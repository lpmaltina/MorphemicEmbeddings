# %% [markdown]
# # Эмбеддинги на основе однокоренных слов

# %%
# !pip install wget
# !pip install morfessor
# !pip install russian_tagsets
# !pip install deeppavlov
# !pip install wordfreq
# !pip install gensim==3.8.2
# Out:
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=a2c17fa08e8449c0983799fb55c7bd2d175a3b9bc084611e5c78bd61fbbc7c36
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Collecting morfessor
#   Downloading https://files.pythonhosted.org/packages/39/e6/7afea30be2ee4d29ce9de0fa53acbb033163615f849515c0b1956ad074ee/Morfessor-2.0.6-py3-none-any.whl
# Installing collected packages: morfessor
# Successfully installed morfessor-2.0.6
# Collecting russian_tagsets
#   Downloading https://files.pythonhosted.org/packages/2d/b1/c9377d472a04fb9b84f59365560d68b5d868b589691f32545eb606b3be48/russian-tagsets-0.6.tar.gz
# Building wheels for collected packages: russian-tagsets
#   Building wheel for russian-tagsets (setup.py) ... done
#   Created wheel for russian-tagsets: filename=russian_tagsets-0.6-cp36-none-any.whl size=24636 sha256=de34253da4308697f823efcb5f7fbcbfd95e68fac1b2f84466c9bb18059773ff
#   Stored in directory: /root/.cache/pip/wheels/e8/9d/dd/4679aca4031fdb0d3ad65e165ba5343e61441ed7ad587a08e6
# Successfully built russian-tagsets
# Installing collected packages: russian-tagsets
# Successfully installed russian-tagsets-0.6
# Collecting deeppavlov
#   Downloading https://files.pythonhosted.org/packages/63/25/7c97c184d13c579ddc4550f58c0c4fc480a6122393008c21c4e4fad6d64d/deeppavlov-0.11.0-py3-none-any.whl (847kB)
#      |████████████████████████████████| 849kB 2.9MB/s
# Collecting nltk==3.4.5
#   Downloading https://files.pythonhosted.org/packages/f6/1d/d925cfb4f324ede997f6d47bea4d9babba51b49e87a767c170b77005889d/nltk-3.4.5.zip (1.5MB)
#      |████████████████████████████████| 1.5MB 17.3MB/s
# Collecting uvicorn==0.11.1
#   Downloading https://files.pythonhosted.org/packages/8e/24/11f4b4bf3963ead6de570feeae49eeced02f6768cf1f68e16f4b16d3b0aa/uvicorn-0.11.1-py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 6.6MB/s
# Collecting pytz==2019.1
#   Downloading https://files.pythonhosted.org/packages/3d/73/fe30c2daaaa0713420d0382b16fbb761409f532c56bdcc514bf7b6262bb6/pytz-2019.1-py2.py3-none-any.whl (510kB)
#      |████████████████████████████████| 512kB 20.3MB/s
# Collecting pyopenssl==19.1.0
#   Downloading https://files.pythonhosted.org/packages/9e/de/f8342b68fa9e981d348039954657bdf681b2ab93de27443be51865ffa310/pyOpenSSL-19.1.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 6.6MB/s
# Requirement already satisfied: tqdm==4.41.1 in /usr/local/lib/python3.6/dist-packages (from deeppavlov) (4.41.1)
# Collecting ruamel.yaml==0.15.100
#   Downloading https://files.pythonhosted.org/packages/e7/9f/83bb34eaf84032b0b54fcc4a6aff1858572d279d65a301c7ae875f523df5/ruamel.yaml-0.15.100-cp36-cp36m-manylinux1_x86_64.whl (656kB)
#      |████████████████████████████████| 665kB 18.6MB/s
# Collecting pandas==0.25.3
#   Downloading https://files.pythonhosted.org/packages/52/3f/f6a428599e0d4497e1595030965b5ba455fd8ade6e977e3c819973c4b41d/pandas-0.25.3-cp36-cp36m-manylinux1_x86_64.whl (10.4MB)
#      |████████████████████████████████| 10.4MB 32.3MB/s
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from deeppavlov) (1.4.1)
# Collecting Cython==0.29.14
#   Downloading https://files.pythonhosted.org/packages/df/d1/4d3f8a7a920e805488a966cc6ab55c978a712240f584445d703c08b9f405/Cython-0.29.14-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 45.4MB/s
# Collecting scikit-learn==0.21.2
#   Downloading https://files.pythonhosted.org/packages/85/04/49633f490f726da6e454fddc8e938bbb5bfed2001681118d3814c219b723/scikit_learn-0.21.2-cp36-cp36m-manylinux1_x86_64.whl (6.7MB)
#      |████████████████████████████████| 6.7MB 50.0MB/s
# Collecting requests==2.22.0
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 7.4MB/s
# Collecting pytelegrambotapi==3.6.7
#   Downloading https://files.pythonhosted.org/packages/62/ab/99c606f69fcda57e35788b913dd34c9d9acb48dd26349141b3855dcf6351/pyTelegramBotAPI-3.6.7.tar.gz (65kB)
#      |████████████████████████████████| 71kB 8.1MB/s
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.6/dist-packages (from deeppavlov) (2.10.0)
# Collecting pymorphy2-dicts-ru
#   Downloading https://files.pythonhosted.org/packages/7c/9b/358faaff410f65a4ad159275e897b5956dcb20576c5b8e764b971c1634d7/pymorphy2_dicts_ru-2.4.404381.4453942-py2.py3-none-any.whl (8.0MB)
#      |████████████████████████████████| 8.0MB 21.4MB/s
# Collecting pydantic==1.3
#   Downloading https://files.pythonhosted.org/packages/99/24/e78cf017628e7eaed20cb040999b1ecc69f872da53dfd0d9aed40c0fa5f1/pydantic-1.3-cp36-cp36m-manylinux2010_x86_64.whl (7.3MB)
#      |████████████████████████████████| 7.3MB 40.1MB/s
# Collecting rusenttokenize==0.0.5
#   Downloading https://files.pythonhosted.org/packages/25/4c/a2f00be5def774a3df2e5387145f1cb54e324607ec4a7e23f573645946e7/rusenttokenize-0.0.5-py3-none-any.whl
# Collecting numpy==1.18.0
#   Downloading https://files.pythonhosted.org/packages/92/e6/45f71bd24f4e37629e9db5fb75caab919507deae6a5a257f9e4685a5f931/numpy-1.18.0-cp36-cp36m-manylinux1_x86_64.whl (20.1MB)
#      |████████████████████████████████| 20.1MB 1.2MB/s
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.6/dist-packages (from deeppavlov) (7.1.2)
# Collecting aio-pika==6.4.1
#   Downloading https://files.pythonhosted.org/packages/c8/07/196a4115cbef31fa0c3dabdea146f02dffe5e49998341d20dbe2278953bc/aio_pika-6.4.1-py3-none-any.whl (40kB)
#      |████████████████████████████████| 51kB 6.7MB/s
# Collecting overrides==2.7.0
#   Downloading https://files.pythonhosted.org/packages/ac/98/2430afd204c48ac0a529d439d7e22df8fa603c668d03456b5947cb59ec36/overrides-2.7.0.tar.gz
# Collecting fastapi==0.47.1
#   Downloading https://files.pythonhosted.org/packages/a3/a7/4804d7abf8a1544d079d50650af872387154ebdac5bd07d54b2e60e2b334/fastapi-0.47.1-py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 5.4MB/s
# Collecting sacremoses==0.0.35
#   Downloading https://files.pythonhosted.org/packages/1f/8e/ed5364a06a9ba720fddd9820155cc57300d28f5f43a6fd7b7e817177e642/sacremoses-0.0.35.tar.gz (859kB)
#      |████████████████████████████████| 860kB 46.5MB/s
# Collecting pymorphy2==0.8
#   Downloading https://files.pythonhosted.org/packages/a3/33/fff9675c68b5f6c63ec8c6e6ff57827dda28a1fa5b2c2d727dffff92dd47/pymorphy2-0.8-py2.py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 6.2MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk==3.4.5->deeppavlov) (1.12.0)
# Collecting websockets==8.*
#   Downloading https://files.pythonhosted.org/packages/bb/d9/856af84843912e2853b1b6e898ac8b802989fcf9ecf8e8445a1da263bf3b/websockets-8.1-cp36-cp36m-manylinux2010_x86_64.whl (78kB)
#      |████████████████████████████████| 81kB 8.4MB/s
# Collecting uvloop>=0.14.0; sys_platform != "win32" and sys_platform != "cygwin" and platform_python_implementation != "pypy"
#   Downloading https://files.pythonhosted.org/packages/41/48/586225bbb02d3bdca475b17e4be5ce5b3f09da2d6979f359916c1592a687/uvloop-0.14.0-cp36-cp36m-manylinux2010_x86_64.whl (3.9MB)
#      |████████████████████████████████| 3.9MB 44.9MB/s
# Collecting httptools==0.0.13; sys_platform != "win32" and sys_platform != "cygwin" and platform_python_implementation != "pypy"
#   Downloading https://files.pythonhosted.org/packages/1b/03/215969db11abe8741e9c266a4cbe803a372bd86dd35fa0084c4df6d4bd00/httptools-0.0.13.tar.gz (104kB)
#      |████████████████████████████████| 112kB 52.2MB/s
# Collecting h11<0.10,>=0.8
#   Downloading https://files.pythonhosted.org/packages/5a/fd/3dad730b0f95e78aeeb742f96fa7bbecbdd56a58e405d3da440d5bfb90c6/h11-0.9.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 7.8MB/s
# Collecting cryptography>=2.8
#   Downloading https://files.pythonhosted.org/packages/3c/04/686efee2dcdd25aecf357992e7d9362f443eb182ecd623f882bc9f7a6bba/cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 41.4MB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas==0.25.3->deeppavlov) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn==0.21.2->deeppavlov) (0.16.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests==2.22.0->deeppavlov) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests==2.22.0->deeppavlov) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests==2.22.0->deeppavlov) (1.24.3)
# Collecting idna<2.9,>=2.5
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 7.6MB/s
# Requirement already satisfied: dataclasses>=0.6; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from pydantic==1.3->deeppavlov) (0.7)
# Collecting yarl
#   Downloading https://files.pythonhosted.org/packages/95/8f/0209fc5d975f839344c33c822ff2f7ef80f6b1e984673a5a68f960bfa583/yarl-1.4.2-cp36-cp36m-manylinux1_x86_64.whl (252kB)
#      |████████████████████████████████| 256kB 52.4MB/s
# Collecting aiormq<4,>=3.2.0
#   Downloading https://files.pythonhosted.org/packages/ed/90/e8089608c2fcf75d6a8ff805611a1e31ed7cc523f5eafe244a2fb3dd75b8/aiormq-3.2.2-py3-none-any.whl
# Collecting starlette<=0.12.9,>=0.12.9
#   Downloading https://files.pythonhosted.org/packages/67/95/2220fe5bf287e693a6430d8ee36c681b0157035b7249ec08f8fb36319d16/starlette-0.12.9.tar.gz (46kB)
#      |████████████████████████████████| 51kB 6.4MB/s
# Collecting dawg-python>=0.7
#   Downloading https://files.pythonhosted.org/packages/6a/84/ff1ce2071d4c650ec85745766c0047ccc3b5036f1d03559fd46bb38b5eeb/DAWG_Python-0.7.2-py2.py3-none-any.whl
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.6/dist-packages (from pymorphy2==0.8->deeppavlov) (0.6.2)
# Collecting pymorphy2-dicts<3.0,>=2.4
#   Downloading https://files.pythonhosted.org/packages/02/51/2465fd4f72328ab50877b54777764d928da8cb15b74e2680fc1bd8cb3173/pymorphy2_dicts-2.4.393442.3710985-py2.py3-none-any.whl (7.1MB)
#      |████████████████████████████████| 7.1MB 14.0MB/s
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.8->pyopenssl==19.1.0->deeppavlov) (1.14.0)
# Collecting multidict>=4.0
#   Downloading https://files.pythonhosted.org/packages/1a/95/f50352b5366e7d579e8b99631680a9e32e1b22adfa1629a8f23b1d22d5e2/multidict-4.7.6-cp36-cp36m-manylinux1_x86_64.whl (148kB)
#      |████████████████████████████████| 153kB 53.7MB/s
# Collecting pamqp==2.3.0
#   Downloading https://files.pythonhosted.org/packages/eb/56/afa06143361e640c9159d828dadc95fc9195c52c95b4a97d136617b0166d/pamqp-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.8->pyopenssl==19.1.0->deeppavlov) (2.20)
# Building wheels for collected packages: nltk, pytelegrambotapi, overrides, sacremoses, httptools, starlette
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449906 sha256=4f75d9a60973e7bc011ea8c413667493ba344949e4ff37a0af7ed084d0c7b77b
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
#   Building wheel for pytelegrambotapi (setup.py) ... done
#   Created wheel for pytelegrambotapi: filename=pyTelegramBotAPI-3.6.7-cp36-none-any.whl size=47178 sha256=d5e72b5620f491f7bb40ffd930898e1006e2b4e430ca9301c9e5a83eb05a83f6
#   Stored in directory: /root/.cache/pip/wheels/23/40/18/8a34153f95ef0dc19e3954898e5a5079244b76a8afdd7d0ec5
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-2.7.0-cp36-none-any.whl size=5600 sha256=ad445fb4f2b80d5e8cbc71421413d610b22a369480d4ece251b0a6da363f419e
#   Stored in directory: /root/.cache/pip/wheels/8c/7c/ef/80508418b67d87371c5b3de49e03eb22ee7c1d19affb5099f8
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.35-cp36-none-any.whl size=883999 sha256=35dbaee1ab88f1f895bb9a17c563e6c4a93cb15de551e86fa0205e019f7774c9
#   Stored in directory: /root/.cache/pip/wheels/63/2a/db/63e2909042c634ef551d0d9ac825b2b0b32dede4a6d87ddc94
#   Building wheel for httptools (setup.py) ... done
#   Created wheel for httptools: filename=httptools-0.0.13-cp36-cp36m-linux_x86_64.whl size=212529 sha256=0e3b0199af7fe7cec77f8e3bb5b5ddb6e86ee77eac3cec908af444dcba5a95ac
#   Stored in directory: /root/.cache/pip/wheels/e8/3e/2e/013f99b42efc25cf3589730cf380738e46b1e5edaf2f78d525
#   Building wheel for starlette (setup.py) ... done
#   Created wheel for starlette: filename=starlette-0.12.9-cp36-none-any.whl size=57245 sha256=bd12a1b998cd25fa3e3a886a7097cac81acf0c3d6c17e91179a216cb17f2b6bb
#   Stored in directory: /root/.cache/pip/wheels/1c/51/5b/3828d52e185cafad941c4291b6f70894d0794be28c70addae5
# Successfully built nltk pytelegrambotapi overrides sacremoses httptools starlette
# ERROR: google-colab 1.0.0 has requirement pandas~=1.0.0; python_version >= "3.0", but you'll have pandas 0.25.3 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.22.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: nltk, websockets, uvloop, httptools, h11, uvicorn, pytz, cryptography, pyopenssl, ruamel.yaml, numpy, pandas, Cython, scikit-learn, idna, requests, pytelegrambotapi, pymorphy2-dicts-ru, pydantic, rusenttokenize, multidict, yarl, pamqp, aiormq, aio-pika, overrides, starlette, fastapi, sacremoses, dawg-python, pymorphy2-dicts, pymorphy2, deeppavlov
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
#   Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
#   Found existing installation: Cython 0.29.21
#     Uninstalling Cython-0.29.21:
#       Successfully uninstalled Cython-0.29.21
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed Cython-0.29.14 aio-pika-6.4.1 aiormq-3.2.2 cryptography-2.9.2 dawg-python-0.7.2 deeppavlov-0.11.0 fastapi-0.47.1 h11-0.9.0 httptools-0.0.13 idna-2.8 multidict-4.7.6 nltk-3.4.5 numpy-1.18.0 overrides-2.7.0 pamqp-2.3.0 pandas-0.25.3 pydantic-1.3 pymorphy2-0.8 pymorphy2-dicts-2.4.393442.3710985 pymorphy2-dicts-ru-2.4.404381.4453942 pyopenssl-19.1.0 pytelegrambotapi-3.6.7 pytz-2019.1 requests-2.22.0 ruamel.yaml-0.15.100 rusenttokenize-0.0.5 sacremoses-0.0.35 scikit-learn-0.21.2 starlette-0.12.9 uvicorn-0.11.1 uvloop-0.14.0 websockets-8.1 yarl-1.4.2
# Collecting wordfreq
#   Downloading https://files.pythonhosted.org/packages/8f/24/a4c3d79335c2c35d84d1728614ff9115999f7218f30f73f29c81778accc7/wordfreq-2.3.2.tar.gz (32.8MB)
#      |████████████████████████████████| 32.8MB 126kB/s
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.6/dist-packages (from wordfreq) (1.0.0)
# Collecting langcodes>=2
#   Downloading https://files.pythonhosted.org/packages/52/1d/9b5ad179234206ad52f863c314851db7a00f69770c51d40c12c7513e628f/langcodes-2.0.0.tar.gz (4.9MB)
#      |████████████████████████████████| 4.9MB 38.9MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from wordfreq) (2019.12.20)
# Collecting marisa-trie
#   Downloading https://files.pythonhosted.org/packages/20/95/d23071d0992dabcb61c948fb118a90683193befc88c23e745b050a29e7db/marisa-trie-0.7.5.tar.gz (270kB)
#      |████████████████████████████████| 276kB 44.2MB/s
# Building wheels for collected packages: wordfreq, langcodes, marisa-trie
#   Building wheel for wordfreq (setup.py) ... done
#   Created wheel for wordfreq: filename=wordfreq-2.3.2-cp36-none-any.whl size=32817238 sha256=ea7b97f5c0aae57476a0fd5bcfca614416392b1a2b0afcab7f45a957876afc52
#   Stored in directory: /root/.cache/pip/wheels/8d/ba/84/ba6be76208bd2c2124b6586f7967fb87e9f9fb4b4827e5e2c9
#   Building wheel for langcodes (setup.py) ... done
#   Created wheel for langcodes: filename=langcodes-2.0.0-cp36-none-any.whl size=5044047 sha256=347d9de7d316209ec49360fff4381eccfefcf297d23a0cdc83b649d32fc5940c
#   Stored in directory: /root/.cache/pip/wheels/c9/11/90/c7bba8118f3674d75e1457537635266a12538cf622a4684bb2
#   Building wheel for marisa-trie (setup.py) ... done
#   Created wheel for marisa-trie: filename=marisa_trie-0.7.5-cp36-cp36m-linux_x86_64.whl size=861428 sha256=9788d86eddd7d1ad596ab17ded465d6dbfbdac23c1fb3700e35d85fe572b3f1b
#   Stored in directory: /root/.cache/pip/wheels/45/24/79/022624fc914f0e559fe8a1141aaff1f9df810905a13fc75d57
# Successfully built wordfreq langcodes marisa-trie
# Installing collected packages: marisa-trie, langcodes, wordfreq
# Successfully installed langcodes-2.0.0 marisa-trie-0.7.5 wordfreq-2.3.2
# Collecting gensim==3.8.2
#   Downloading https://files.pythonhosted.org/packages/1a/b3/8358842ee8e430f7eb8f996bdd06c146a71712b9848ed32f949ad44b5adf/gensim-3.8.2-cp36-cp36m-manylinux1_x86_64.whl (24.2MB)
#      |████████████████████████████████| 24.2MB 26.0MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim==3.8.2) (1.18.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.6/dist-packages (from gensim==3.8.2) (2.1.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim==3.8.2) (1.12.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from gensim==3.8.2) (1.4.1)
# Requirement already satisfied: boto in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim==3.8.2) (2.49.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim==3.8.2) (2.22.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim==3.8.2) (1.14.20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim==3.8.2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim==3.8.2) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim==3.8.2) (2020.6.20)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim==3.8.2) (2.8)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim==3.8.2) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim==3.8.2) (0.3.3)
# Requirement already satisfied: botocore<1.18.0,>=1.17.20 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim==3.8.2) (1.17.20)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.20->boto3->smart-open>=1.8.1->gensim==3.8.2) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.20->boto3->smart-open>=1.8.1->gensim==3.8.2) (2.8.1)
# Installing collected packages: gensim
#   Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-3.8.2

# %%
import os
import re 
import random
import json
import copy
import wordfreq
import numpy as np
import morfessor
import gensim
from deeppavlov import build_model, configs
from scipy.stats import spearmanr

# %% [markdown]
# ## Морфемный анализ словаря word2vec модели

# %%
def read_morphemic_analyses(filename, words, probs):
    '''Функция для считывания результатов морфемного анализа.

    Аргументы функции:
    - filename - имя файла, в котором записаны результаты морфемного анализа
    - words - список слов (с частеречными тегами), для которых проведён морфемный анализ
    - probs - True, если в файле с результатами морфемного анализа есть вероятности морфов,
    иначе - False

    Функция возвращает cловарь, ключ которого - слово (с частеречным тегом), значение - разбор.
    Разбор - список морфов. 
    Каждый из морфов в свою очередь задан в виде списка: 
    0-ой элемент - морф, 
    1-ый элемент - тип морфа,
    2-ой элемент - вероятность морфа (присутствует, если аргумент probs=True)'''

    with open(filename) as f:
        data = f.read().strip().split('\n')
    
    if probs:
        analyses = [[m.split('\t') for m in '\t'.join(w.split('\t')[1:-1]).split('/')] for w in data]
        probs = [[float(n) for m in w.split('\t')[-1].split('/') for n in m.split()] for w in data]
        analyses_with_probs = [[m+[probs[iw][im]] for im, m in enumerate(w)]
                for iw, w in enumerate(analyses)] 
        data = dict(zip(words, analyses_with_probs))
    else:
        analyses = [[m.split('\t') for m in '\t'.join(w.split('\t')[1:]).split('/')] for w in data]
        data = dict(zip(words, analyses))
    return data

# %%
def morphemic_analysis(words, dataset):
    '''Функция для выполнения морфемного анализа.

    Аргументы функции:
    - words - список слов (с частеречными тегами), для которых проведён морфемный анализ
    - dataset - название датасета, для слов которого выполняется морфемный анализ

    Что делает функция:
    1) записывает список слов в файл, удаляя их частеречные теги
    2) создаёт для данного датасета файл с конфигурацией
    3) выполняет морфемный анализ слов из этого датасета c помощью моделей Morfessor и CNN
    4) считывает результаты морфемного анализа
     
    Функция возвращает cловарь, ключ которого - слово, значение - разбор.
    Разбор - список морфов. 
    Каждый из морфов в свою очередь задан в виде списка: 
    0-ой элемент - морф, 
    1-ый элемент - тип морфа,
    2-ой элемент - вероятность морфа (если probs=True)'''
    
    if not os.path.isfile('MorphemicEmbeddings/Data/{}.txt'.format(dataset)):
        print('Saving {} for morphemic analysis...'.format(dataset))
        with open('MorphemicEmbeddings/Data/{}.txt'.format(dataset), 'w') as f:
            f.write('\n'.join([w.split('_')[0] for w in words]))

    if not os.path.isfile('MorphemicEmbeddings/MorfessorMorphSegm/results/res_{}.txt'.format(dataset)):
        print('Segmenting {} into morphemes with Morfessor model...'.format(dataset))
        io = morfessor.MorfessorIO()
        model_morfessor = io.read_binary_model_file(
            'MorphemicEmbeddings/MorfessorMorphSegm/models/notlemma_types_alpha0.1_beta1000.bin')  
        
        analyses = []
        for word in words:
            word = word.split('_')[0]
            try:
                morphs = model_morfessor.segment(word)
            except KeyError:
                morphs = model_morfessor.viterbi_segment(word)[0]
            analysis = '/'.join([m+'\t'+'AFFIX'  if m in affixes else m+'\t'+'ROOT' for m in morphs])
            analyses.append(analysis)
            
        with open('MorphemicEmbeddings/MorfessorMorphSegm/results/res_{}.txt'.format(dataset),
                  'w', encoding='utf-8') as f:
            f.write('\n'.join([words[i] +'\t'+analyses[i] for i in range(len(words))]))

    data_morfessor = read_morphemic_analyses( 
        'MorphemicEmbeddings/MorfessorMorphSegm/results/res_{}.txt'.format(dataset), words, probs=False)
         
    if not os.path.isfile('MorphemicEmbeddings/NeuralMorphSegm/config/config_{}.txt'.format(dataset)):
        print('Creating configuration file for CNN model...')
        morph_config = {"load_file": "MorphemicEmbeddings/NeuralMorphSegm/models/model15.json",
                "model_file": "MorphemicEmbeddings/NeuralMorphSegm/model15.hdf5",
                "test_file": "MorphemicEmbeddings/Data/{}.txt".format(dataset),
                "outfile": "MorphemicEmbeddings/NeuralMorphSegm/results/res_{}.txt".format(dataset)}
                            
        with open("MorphemicEmbeddings/NeuralMorphSegm/config/config_{}.json".format(dataset), 'w') as f:
            json.dump(morph_config, f)

    if not os.path.isfile('MorphemicEmbeddings/NeuralMorphSegm/results/res_{}.txt'.format(dataset)):
        print('Segmenting {} into morphemes with CNN model...'.format(dataset)) 
        # !python "MorphemicEmbeddings/NeuralMorphSegm/neural_morph_segm.py" "MorphemicEmbeddings/NeuralMorphSegm/config/config_{dataset}.json"

    data_cnn = read_morphemic_analyses(
        'MorphemicEmbeddings/NeuralMorphSegm/results/res_{}.txt'.format(dataset), words, probs=True)
    return data_morfessor, data_cnn

# %%
def load_model(model_type, corpus):
    '''Функция для скачивания и загрузки предобученных эмбеддингов слов.

    Аргументы функции:
    - model_type - тип модели эмбеддингов ('word2vec' или 'fasttext')
    - corpus - название корпуса, на котором обучалась модель эмбеддингов 
    ('RNC', 'Araneum', 'Tayga')

    Функция создаёт папку {model_type}{corpus} и помещает туда файлы, скачанные по ссылке.
    Если скачанный файл имеет расширение zip или tgz, он распаковывается.
    Если среди полученных файлов есть файл с расширением vec, txt или vec.gz,
    считываются векторы из этого файла.
    Если такого файла нет, модель загружается из файла с расширением model.

    Функция возвращает загруженную модель.'''

    folder = '{}{}'.format(model_type, corpus)

    if not os.path.exists(folder): 
        os.mkdir(folder)
        print('Downloading {} model ({})...'.format(model_type, corpus))
        url = models[model_type][corpus]
        filename = !(basename "$url")
        filename = filename[0]
        # !wget -O {filename} "$url" 

        if filename.endswith('.zip'):
            # !unzip {filename} -d {folder}
            # !rm {filename}
        elif filename.endswith('.tgz'):
            # !tar xzf {filename} -C {folder}  
            # !rm {filename}    
        else:
            # !mv {filename} {folder}

    filenames = os.listdir(folder) 
    
    print('Loading {} model ({})...'.format(model_type, corpus))
    for filename in filenames:
        if filename.endswith('.vec') or filename.endswith('.txt') or filename.endswith('.vec.gz'):
            model = gensim.models.KeyedVectors.load_word2vec_format('{}/{}'.format(folder, filename))
            break
    else:
        for filename in filenames:
            if filename.endswith('.model'):
                model = gensim.models.KeyedVectors.load('{}/{}'.format(folder, filename))
    return model

# %%
def load_model_preprocess_vocab(corpus):
    '''Функция, которая:
    1) загружает word2vec модель, обученную на указанном корпусе
    2) формирует список слов, для которых выполняется морфемный анализ, и записывает их в файл.
    Это слова из словаря word2vec модели, 
    которые могут содержать только буквы русского языка и дефисы
    3) выполняет морфемный анализ этих слов
    
    Аргументы функции:
    - corpus - название корпуса, на котором обучалась модель эмбеддингов 
    ('RNC', 'Araneum', 'Tayga')
    
    Функция возвращает:
    1) word2vec модель
    2) список морфемных разборов для слов. 
    Для каждого слова разбор - это список морфов. 
    Каждый из морфов в свою очередь задан в виде списка: 
    0-ой элемент - морф, 
    1-ый элемент - тип морфа,
    2-ой элемент - вероятность морфа (если для морфемного анализа используется CNN-модель)'''
    
    model = load_model('word2vec', corpus)
    reg_exp = re.compile('[А-Яа-яЁё-]+')
    words = list(model.vocab.keys())
    words = [w for w in words if re.fullmatch(reg_exp, w.split('_')[0])]
    data_w2v_morfessor, data_w2v_cnn = morphemic_analysis(words, 'word2vec_{}_vocab'.format(corpus))
    return model, data_w2v_morfessor, data_w2v_cnn

# %% [markdown]
# ## Морфемный анализ OOV-слов

# %%
model_tagging = build_model(configs.morpho_tagger.UD2_0.morpho_ru_syntagrus_pymorphy, download=True)
# Out:
# 2020-07-15 19:42:57.934 INFO in 'deeppavlov.core.data.utils'['utils'] at line 94: Downloading from http://files.deeppavlov.ai/datasets/UD2.0_source/ru_syntagrus.tar.gz to /root/.deeppavlov/downloads/UD2.0_source/ru_syntagrus.tar.gz
# 100%|██████████| 18.0M/18.0M [00:04<00:00, 4.47MB/s]
# 2020-07-15 19:43:02.251 INFO in 'deeppavlov.core.data.utils'['utils'] at line 269: Extracting /root/.deeppavlov/downloads/UD2.0_source/ru_syntagrus.tar.gz archive into /root/.deeppavlov/downloads/UD2.0_source/ru_syntagrus
# 2020-07-15 19:43:03.566 INFO in 'deeppavlov.core.data.utils'['utils'] at line 94: Downloading from http://files.deeppavlov.ai/deeppavlov_data/morpho_tagger/UD2.0/ru_syntagrus.tar.gz to /root/.deeppavlov/models/morpho_tagger/UD2.0/ru_syntagrus.tar.gz
# 100%|██████████| 30.7M/30.7M [00:06<00:00, 4.84MB/s]
# 2020-07-15 19:43:10.188 INFO in 'deeppavlov.core.data.utils'['utils'] at line 269: Extracting /root/.deeppavlov/models/morpho_tagger/UD2.0/ru_syntagrus.tar.gz archive into /root/.deeppavlov/models/morpho_tagger/UD2.0/ru_syntagrus
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package perluniprops to /root/nltk_data...
# [nltk_data]   Unzipping misc/perluniprops.zip.
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping corpora/nonbreaking_prefixes.zip.
# 2020-07-15 19:43:12.237 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /root/.deeppavlov/models/morpho_tagger/UD2.0/ru_syntagrus/tag.dict]
# 2020-07-15 19:43:12.241 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /root/.deeppavlov/models/morpho_tagger/UD2.0/ru_syntagrus/char.dict]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/deeppavlov/core/models/tf_backend.py:38: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# 2020-07-15 19:43:14.132 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['morpho_tagger'] at line 166: 99 symbols, 711 tags in CharacterTagger
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-07-15 19:43:15.538 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 192: Model: "model"
# 2020-07-15 19:43:15.538 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 193: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.540 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: Layer (type)                    Output Shape         Param #     Connected to
# 2020-07-15 19:43:15.545 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 195: ==================================================================================================
# 2020-07-15 19:43:15.547 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: input_1 (InputLayer)            [(None, None, 32)]   0
# 2020-07-15 19:43:15.548 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.549 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: lambda (Lambda)                 (None, None, 32, 99) 0           input_1[0][0]
# 2020-07-15 19:43:15.550 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.551 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: dense (Dense)                   (None, None, 32, 32) 3168        lambda[0][0]
# 2020-07-15 19:43:15.552 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.554 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: conv2d (Conv2D)                 (None, None, 32, 50) 1650        dense[0][0]
# 2020-07-15 19:43:15.555 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.556 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: conv2d_1 (Conv2D)               (None, None, 32, 100 6500        dense[0][0]
# 2020-07-15 19:43:15.558 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.559 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: conv2d_2 (Conv2D)               (None, None, 32, 150 14550       dense[0][0]
# 2020-07-15 19:43:15.560 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.561 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: conv2d_3 (Conv2D)               (None, None, 32, 200 25800       dense[0][0]
# 2020-07-15 19:43:15.562 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.563 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: conv2d_4 (Conv2D)               (None, None, 32, 200 32200       dense[0][0]
# 2020-07-15 19:43:15.564 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.565 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: conv2d_5 (Conv2D)               (None, None, 32, 200 38600       dense[0][0]
# 2020-07-15 19:43:15.566 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.567 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: conv2d_6 (Conv2D)               (None, None, 32, 200 45000       dense[0][0]
# 2020-07-15 19:43:15.568 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.569 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: concatenate (Concatenate)       (None, None, 32, 110 0           conv2d[0][0]
# 2020-07-15 19:43:15.570 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190:                                                                  conv2d_1[0][0]
# 2020-07-15 19:43:15.570 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190:                                                                  conv2d_2[0][0]
# 2020-07-15 19:43:15.571 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190:                                                                  conv2d_3[0][0]
# 2020-07-15 19:43:15.572 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190:                                                                  conv2d_4[0][0]
# 2020-07-15 19:43:15.573 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190:                                                                  conv2d_5[0][0]
# 2020-07-15 19:43:15.574 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190:                                                                  conv2d_6[0][0]
# 2020-07-15 19:43:15.575 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.576 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: lambda_1 (Lambda)               (None, None, 1100)   0           concatenate[0][0]
# 2020-07-15 19:43:15.576 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.577 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: input_2 (InputLayer)            [(None, None, 724)]  0
# 2020-07-15 19:43:15.578 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.579 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: highway (Highway)               (None, None, 1100)   2422200     lambda_1[0][0]
# 2020-07-15 19:43:15.580 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.581 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: dense_1 (Dense)                 (None, None, 128)    92800       input_2[0][0]
# 2020-07-15 19:43:15.582 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.582 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: concatenate_1 (Concatenate)     (None, None, 1228)   0           highway[0][0]
# 2020-07-15 19:43:15.583 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190:                                                                  dense_1[0][0]
# 2020-07-15 19:43:15.584 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.585 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: dropout (Dropout)               (None, None, 1228)   0           concatenate_1[0][0]
# 2020-07-15 19:43:15.586 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.587 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: bidirectional (Bidirectional)   (None, None, 256)    1389568     dropout[0][0]
# 2020-07-15 19:43:15.588 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 259: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.589 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 190: p (TimeDistributed)             (None, None, 711)    182727      bidirectional[0][0]
# 2020-07-15 19:43:15.590 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 257: ==================================================================================================
# 2020-07-15 19:43:15.591 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 268: Total params: 4,254,763
# 2020-07-15 19:43:15.592 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 269: Trainable params: 4,254,763
# 2020-07-15 19:43:15.593 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 270: Non-trainable params: 0
# 2020-07-15 19:43:15.594 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['layer_utils'] at line 271: __________________________________________________________________________________________________
# 2020-07-15 19:43:15.595 INFO in 'deeppavlov.models.morpho_tagger.morpho_tagger'['morpho_tagger'] at line 139: [loading model from /root/.deeppavlov/models/morpho_tagger/UD2.0/ru_syntagrus/model_pymorphy.hdf5]

# %%
def add_pos_tag(w):
    '''Функция, которая добавляет к слову его частеречный тег'''
    return w + '_' + model_tagging([w])[0].split('\t')[2]

# %%
def tag_word_simimilarity_data(filename):
    '''Функция, которая считывает датасет для определения семантической близости
    и добавляет для слов частеречные теги.
    
    Функция принимает на вход имя файла - датасета для определения семантической близости.
    Функция возвращает список слов из этого датасета с добавленными частеречными тегами.'''

    word_similarity_tagged, wordlist_similarity_tagged = [], []

    with open('MorphemicEmbeddings/SemanticSimilarity/{}'.format(filename)) as f:
        word_similarity = f.read().strip().split('\n')
        if filename.endswith('.tsv'):
            separator = '\t'
        elif filename.endswith('.csv'):
            separator = ','
            word_similarity = word_similarity[1:]
            
        for line in word_similarity:
            w1, w2, similarity_value = line.split(separator)
            w1, w2 = add_pos_tag(w1), add_pos_tag(w2)
            wordlist_similarity_tagged.extend([w1, w2])  
            word_similarity_tagged.append('{}'.format(separator).join([w1, w2, similarity_value]))

    if not os.path.isfile(
        'MorphemicEmbeddings/SemanticSimilarity/{}_tagged.{}'.format(*filename.split('.'))):
        with open('MorphemicEmbeddings/SemanticSimilarity/{}_tagged.{}'.format(
            *filename.split('.')), 'w') as f:
            f.write('\n'.join(word_similarity_tagged))
    
    return wordlist_similarity_tagged

# %%
def oov_morphemic_analysis(model, corpus):
    '''Функция для морфемного анализа внесловарных слов 
    (слов, отсутствующих в данной word2vec модели).
    
    Аргументы функции:
    - model - модель эмбеддингов
    - corpus - название корпуса, на котором обучалась модель эмбеддингов 
    ('RNC', 'Araneum', 'Tayga')
    
    Функция возвращает результаты морфемного анализа для данных слов,
    полученные с помощью моделей Morfessor и CNN'''

    oov = [w for w in all_wordlists_similarity if w not in model.vocab]
    data_rare_words_morfessor, data_rare_words_cnn = morphemic_analysis(
        oov, 'rare_words_{}'.format(corpus))
    return data_rare_words_morfessor, data_rare_words_cnn

# %% [markdown]
# ## Получение эмбеддингов для OOV-слов на основе однокоренных слов

# %%
def root_words_dict(data, probs):
    '''Функция создаёт словарь с однокоренными словами. 
    
    Аргументы функции:
    - data - словарь "слово - его морфемный анализ"
    - probs - True, если в морфемном анализе слова присутствуют вероятности морфовЮ
    иначе - False

    Функция возвращает словарь с однокоренными словами.
    Ключ словаря - корень, значение - список из кортежей.
    Каждый кортеж содержит два элемента: 
    0-ой элемент - слово (с частеречным тегом), в котором есть этот корень ,
    1-ый элемент - вероятность того, что в этом слове такой корень'''
    
    root_words = {}
    
    if probs:
        for word, morphs in data.items():
            for m in morphs:
                morph_text, morph_type, morph_prob = m
                if morph_type == 'ROOT':
                    if morph_text not in root_words:
                        root_words[morph_text] = [(word, morph_prob)]
                    else:
                        root_words[morph_text].append((word, morph_prob))
    else:
        for word, morphs in data.items():
            for m in morphs:
                morph_text, morph_type = m
                if morph_type == 'ROOT':
                    if morph_text not in root_words:
                        root_words[morph_text] = [word]
                    else:
                        root_words[morph_text].append(word)
    return root_words

# %%
def get_weighted_emb(model, cognate_words, weights):
    '''Функция для получения взвешенного эмбеддинга для одного слова
    
    Аргументы функции:
    - model - используемая word2vec модель
    - cognate_words - список однокоренных слов
    - weights - список весов для каждого из этих однокоренных слов

    Функция возвращает взвешенный эмбеддинг для одного слова'''

    emb_weighted = np.zeros((model.vector_size, len(cognate_words)))

    for i, w in enumerate(cognate_words):
        emb_weighted[:, i] = model[w] * weights[w]

    sum_weights = sum(list(weights.values()))
    emb_weighted = np.sum(emb_weighted, axis=1)/sum_weights
    return emb_weighted

# %%
def morphemic_f1(data_oov, data_vocab, target_word, cognate_word):
    '''Функция, которая вычисляет "морфемную F-меру" - 
    это метрика, которая характеризует то, насколько совпадают 
    морфы исходного слова и морфы для слова, которое является для него однокоренным.

    - True positive: кол-во морфов, совпадающих в исходном слове и однокоренном  для него. 
    Корень берётся с весом 1, префикс, суффикс, постфикс – с весом 0.3, 
    окончания и соединительные гласные не учитываются 

    - False positive: кол-во морфов, которые есть в однокоренном слове, 
    но отсутствуют в исходном. Веса берутся аналогично

    - True negative: кол-во морфов, которые есть в исходном слове слове, 
    но отсутствуют в однокоренном для него. Веса берутся аналогично
    
    
    Аргументы функции: 
    - data_oov - словарь "слово - его морфемный анализ" для OOV-слов, 
    - data_vocab - словарь "слово - его морфемный анализ" для слов,
    которые есть в словаре word2vec модели
    - target_word - OOV-слово, для которого мы хотим получить эмбеддинг
    - cognate_word - слово, однокоренное для данного
    
    Функция возвращает морфемную F-меру'''

    weight = {'ROOT': 1, 'PREF': 0.3, 'SUFF': 0.3, 'POSTFIX': 0.3}
    morphs_target_word = set([m[0]+'_'+str(m[1]) for m in data_oov[target_word]
                             if m[1] in {'ROOT', 'PREF', 'SUFF', 'POSTFIX'}])
    morphs_cognate_word = set([m[0]+'_'+str(m[1]) for m in data_vocab[cognate_word]
                             if m[1] in {'ROOT', 'PREF', 'SUFF', 'POSTFIX'}])
    
    def weighted_sum(lst):
        return sum([weight[el.split('_')[1]] for el in lst])

    tp = weighted_sum(morphs_target_word & morphs_cognate_word)
    fp = weighted_sum(morphs_cognate_word - morphs_target_word)
    tn = weighted_sum(morphs_target_word - morphs_cognate_word)
    precision = tp/(tp+fp)
    recall = tp/(tp+tn)
    f1 = 2*precision*recall/(precision+recall)
    return f1

# %%
def new_embeddings(model, morphemic_model, data_w2v, data_rare_words, root_words_dct):
    '''Создание новых эмбеддингов на основе однокоренных слов. 
    Функция возвращает OOV-слова, для которых были получены новые эмбеддинги, и сами эмбеддинги.
    
    Способы получения эмбеддингов:

    - Word2vec + averaged: усреднение эмбеддингов всех однокоренных слов

    - Word2vec + frequency weighted: использование всех однокоренных слов с частотными весами

    - Word2vec + probability weighted: 
    использование всех однокоренных слов с весами-вероятностями того, 
    что в данном слове был верно выделен корень 

    - Word2vec + averaged with top frequencies: 
    на каждый корень слова берётся по 5 однокоренных слов
     с наибольшей частотой, эмбеддинги выбранных слов усредняются 

    - Word2vec + averaged with top probabilities: 
    на каждый корень слова берётся по 5 однокоренных слов 
    с наибольшей вероятностью того, что в данном слове был верно выделен корень,
     эмбеддинги выбранных слов усредняются

    - Word2vec + averaged with top morphemic F1 and frequency: 
    на каждый корень слова берётся по 3 однокоренных слова 
    с наибольшим значением «морфемной F1» и наибольшей частотой, 
    эмбеддинги выбранных слов усредняются

    - Word2vec + averaged with top morphemic F1 and probability:
    на каждый корень слова берётся по 3 однокоренных слова 
    с наибольшим значением «морфемной F1» и наибольшей вероятностью того, 
    что в данном слове был верно выделен корень,
    эмбеддинги выбранных слов усредняются'''
    
    if morphemic_model == 'Morfessor':
        new_words, embs_avg, embs_freq, embs_avg_top_freqs = [], [], [], []

        for target_word, target_word_morphs in data_rare_words.items():
            # находим корень/корни в редком слове
            roots = [morph_text for (morph_text, morph_type) in target_word_morphs 
                     if morph_type == 'ROOT']
            cognate_words, cognates_top_freqs = [], []
            cognates_freqs = {}

            if roots:  # если в слове был найден хотя бы один корень
                # если для этого корня были найдены однокоренные слова, которые есть в word2vec модели
                for root in roots:
                    if root_words_dct.get(root):
                        cognates_freqs[root] = {}
                        for cognate in root_words_dct.get(root):
                            cognate_words.append(cognate)
                            cognates_freqs[root][cognate] = wordfreq.word_frequency(
                                cognate.split('_')[0], 'ru') 
                        cognates_freqs_top_freqs = {k: v for k, v in sorted(cognates_freqs[root].items(),
                            key=lambda item: item[1], reverse=True)[:5]}       
                        cognates_top_freqs.extend(list(cognates_freqs_top_freqs.keys()))
            
            if cognate_words:
                new_words.append(target_word)
                embs_avg.append(np.mean([model[w] for w in set(cognate_words)], axis=0))
                embs_avg_top_freqs.append(np.mean([model[w] for w in set(cognates_top_freqs)], axis=0))
            
                freq_weights = {w: wordfreq.word_frequency(w.split('_')[0], 'ru') for w in cognate_words}
                embs_freq.append(get_weighted_emb(model, cognate_words, freq_weights))

        return new_words, embs_avg, embs_freq, embs_avg_top_freqs
        
    elif morphemic_model == 'CNN':
        new_words, embs_avg, embs_freq, embs_prob, \
        embs_avg_top_probs, embs_avg_top_freqs, \
        embs_avg_f1_freq, embs_avg_f1_prob = [], [], [], [], [], [], [], []

        for target_word, target_word_morphs in data_rare_words.items():
            # находим корень/корни в редком слове
            roots = [morph_text for (morph_text, morph_type, morph_prob) in target_word_morphs
                    if morph_type == 'ROOT']
            cognate_words, cognates_top_freqs, cognates_top_probs, \
            probs_top_freqs, probs_top_probs = [], [], [], [], []
            cognates_f1, cognates_probs, cognates_freqs = {}, {}, {}
            cognates_f1_freqs, cognates_f1_probs = {}, {}

            if roots:  # если в слове был найден хотя бы один корень
                # если для этого корня были найдены однокоренные слова, которые есть в word2vec модели
                for root in roots:
                    if root_words_dct.get(root):
                        cognates_probs[root], cognates_freqs[root], cognates_f1[root] = {}, {}, {}
                        for (cognate, prob) in root_words_dct.get(root):
                            cognate_words.append(cognate)
                            cognates_freqs[root][cognate] = wordfreq.word_frequency(
                                cognate.split('_')[0], 'ru')
                            cognates_probs[root][cognate] = prob
                            cognates_f1[root][cognate] = morphemic_f1(
                                data_rare_words, data_w2v, target_word, cognate)
                        cognates_f1_freq = {k: v for k, v in sorted(cognates_f1[root].items(), 
                            key=lambda item: (item[1], cognates_freqs[root][item[0]]), reverse=True)[:3]}
                        cognates_f1_prob = {k: v for k, v in sorted(cognates_f1[root].items(), 
                            key=lambda item: (item[1], cognates_probs[root][item[0]]), reverse=True)[:3]}
                        
                        for (k, v) in cognates_f1_freq.items():
                            cognates_f1_freqs[k] = v
                        
                        for (k, v) in cognates_f1_prob.items():
                            cognates_f1_probs[k] = v

                        cognates_probs_top_probs = {k: v for k, v in sorted(cognates_probs[root].items(),
                            key=lambda item: item[1], reverse=True)[:5]}      
                        cognates_top_probs.extend(list(cognates_probs_top_probs.keys()))

                        cognates_freqs_top_freqs = {k: v for k, v in sorted(cognates_freqs[root].items(),
                            key=lambda item: item[1], reverse=True)[:5]}       
                        cognates_top_freqs.extend(list(cognates_freqs_top_freqs.keys()))
            
            if cognate_words:
                new_words.append(target_word)
                embs_avg.append(np.mean([model[w] for w in set(cognate_words)], axis=0))
                embs_avg_top_probs.append(np.mean([model[w] for w in set(cognates_top_probs)], axis=0))
                embs_avg_top_freqs.append(np.mean([model[w] for w in set(cognates_top_freqs)], axis=0))
                embs_avg_f1_freq.append(np.mean([model[w] for w in cognates_f1_freqs], axis=0))
                embs_avg_f1_prob.append(np.mean([model[w] for w in cognates_f1_probs], axis=0))
    
                freq_weights = {w: wordfreq.word_frequency(w.split('_')[0], 'ru') for w in cognate_words}
                embs_freq.append(get_weighted_emb(model, cognate_words, freq_weights))

                prob_weights = {k: v for el in cognates_probs.values() for (k, v) in el.items()}
                embs_prob.append(get_weighted_emb(model, cognate_words, prob_weights))
                
        return new_words, embs_avg, embs_freq, embs_prob, embs_avg_top_probs, embs_avg_top_freqs, embs_avg_f1_freq, embs_avg_f1_prob

# %% [markdown]
# ## Применение полученных эмбеддингов для определения семантической близости

# %%
def print_most_similar(model, word):
    '''Функция, которая печатает слова, которые данная модель считает ближайшими к данному слову.
    
    Аргументы функции:
    - model - модель эмбеддингов
    - word - слово, для которого подбираются ближайшие слова'''
    
    print('\nWords similar to {}:'.format(word))
    similar = model.most_similar(word)
    print('\n'.join(['\t'.join([w, str(round(similarity, 4))]) for (w, similarity) in similar]))

# %%
def evaluate(model, model_name, morphemic_model, corpus, 
             similarity_datasets, words2add, embeddings2add):
    '''Функция, которая оценивает качество модели для определения семантической близости.

    Аргументы функции:
    - model - модель эмбеддингов
    - model_name - название модели эмбеддингов
    - morphemic model - модель морфемного анализа
    ('Morfessor', 'CNN', None - для бейзлайнов)
    - corpus - название корпуса, на котором обучалась модель эмбеддингов 
    ('RNC', 'Araneum', 'Tayga')
    - similarity_datasets - названия файлов-датасетов для определения семантической близости

    Что делает функция:
    1) cчитывает файл с парами слов и оценками семантической близости для них
    2) записывает в файл предсказанные значения семантической близости
    3) выводит на экран:
    - корреляцию результатов с экспертной оценкой (корреляция Спирмана)
    - p-value
    - долю OOV-пар
    4) печатает ближайшие слова для указанных слов'''

    for similarity_dataset in similarity_datasets:
        print('\n{} (corpus: {}, morphemic_model: {})'.format(model_name, corpus, morphemic_model))
        print(similarity_dataset.split('.')[0])
        true_similarities, pred_similarities, results = [], [], []
        oov_ratio = 0
            
        with open('MorphemicEmbeddings/SemanticSimilarity/' + similarity_dataset) as f:
            dataset = f.read().strip().split('\n')
        if similarity_dataset.endswith('.tsv'):
            separator = '\t'
        elif similarity_dataset.endswith('.csv'):
            separator = ','
            dataset = dataset[1:]
        
        new_model = copy.deepcopy(model)
        if model_name not in ('Word2vec baseline', 'Word2vec random_vector4unknown',
                              'Word2vec random_similarity4unknown', 'FastText'):
            for i, w in enumerate(words2add):
                if w in rare_words[similarity_dataset]:
                    new_model.add(w, embeddings2add[i])
        
        for line in dataset: 
            w1, w2, true_similarity = line.replace('ё', 'е').split(separator)
            if similarity_dataset.endswith('.tsv'):
                true_similarity = float(true_similarity)/10
            try:
                pred_similarity = new_model.similarity(w1, w2)
            except KeyError:
                if model_name == 'Word2vec random_similarity4unknown':
                    pred_similarity = random.random()
                elif model_name == 'Word2vec random_vector4unknown':
                    if w1 not in new_model.vocab:
                        new_model.add([w1], [np.random.uniform(0, 1, size=300)])
                    if w2 not in new_model.vocab:
                        new_model.add([w2], [np.random.uniform(0, 1, size=300)])
                    pred_similarity = new_model.similarity(w1, w2)
                else:
                    pred_similarity = 0
                    oov_ratio += 1  
            results.append('\t'.join([w1, w2, str(pred_similarity)]))
            true_similarities.append(true_similarity)
            pred_similarities.append(pred_similarity)
            
        with open('MorphemicEmbeddings/SemanticSimilarity/{}-{}-{}-{} results.tsv'.format(
            model_name, corpus, morphemic_model, similarity_dataset.split('.')[0]), 'w') as f:
            f.write('\n'.join(results))

        oov_ratio /= len(dataset)
        spearman_corr, pvalue = spearmanr(true_similarities, pred_similarities)
        print('Spearman correlation for human annotation: {:.4f}'.format(spearman_corr))
        print('p-value: {:.4e}'.format(pvalue))
        print('OOV-pairs ratio: {:.4f}'.format(oov_ratio))
        
        wordlist = words_for_most_similar.get(similarity_dataset)
        if model_name not in ('Word2vec baseline', 'Word2vec random_similarity4unknown') and wordlist:
            for w in wordlist:
                if model_name == 'Fasttext':
                    w = w.split('_')[0]
                print_most_similar(new_model, w)
        print('-'*100)

# %%
def experiment_for_one_corpus(corpus):
    '''Функция, которая получает эмбеддинги на основе однокоренных слов и 
    оценивает их на задаче определения семантической близости.
    Модель принимает на вход название корпуса, на котором были обучены эмбеддинги.'''

    model_w2v, data_w2v_morfessor, data_w2v_cnn = load_model_preprocess_vocab(corpus)
    data_rare_words_morfessor, data_rare_words_cnn = oov_morphemic_analysis(model_w2v, corpus)
    model_fasttext = load_model('fasttext', corpus)

    print('\nEVALUATING ON SEMANTIC SIMILARITY TASK')
        
    evaluate(model_w2v, 'Word2vec baseline', 'None', corpus, 
             word_sim_datasets_tagged, None, None)
        
    new_model = copy.deepcopy(model_w2v)
    evaluate(new_model, 'Word2vec random_vector4unknown', 'None', corpus, 
             word_sim_datasets_tagged, None, None)
    new_model.save_word2vec_format(
        'MorphemicEmbeddings/Word2vec random_vector4unknown {}.vec'.format(corpus))

    evaluate(model_w2v, 'Word2vec random_similarity4unknown', 'None', 
             corpus, word_sim_datasets_tagged, None, None)
    evaluate(model_fasttext,  'FastText', 'None', 
             corpus, word_sim_datasets, None, None)
        
    # словарь, который ставит в соответствие корню слова из word2vec модели, в которых он есть
    root_words_dct = root_words_dict(data_w2v_morfessor, probs=False)
    # получаем эмбеддинги на основе однокоренных слов
    new_words, embs_avg, embs_freq, embs_avg_top_freqs = new_embeddings(
        model_w2v, 'Morfessor', data_w2v_morfessor, data_rare_words_morfessor, root_words_dct)
         
    for model_name, embeddings in {
        'Word2vec + averaged': embs_avg,
        'Word2vec + frequency weighted': embs_freq,
        'Word2vec + averaged with top frequencies': embs_avg_top_freqs}.items():
        evaluate(new_model, model_name, 'Morfessor', corpus,
                 word_sim_datasets_tagged, new_words, embeddings)
        
        
    # словарь, который ставит в соответствие корню слова из word2vec модели, в которых он есть
    root_words_dct = root_words_dict(data_w2v_cnn, probs=True)

    new_words, embs_avg, embs_freq, embs_prob, embs_avg_top_probs,\
        embs_avg_top_freqs, embs_avg_f1_freq, embs_avg_f1_prob = new_embeddings(
                model_w2v, 'CNN', data_w2v_cnn, data_rare_words_cnn, root_words_dct)
        
    for model_name, embeddings in {
        'Word2vec + averaged': embs_avg,
        'Word2vec + frequency weighted': embs_freq,
        'Word2vec + probability weighted': embs_prob,
        'Word2vec + averaged with top frequencies': embs_avg_top_freqs,
        'Word2vec + averaged with top probabilities': embs_avg_top_probs,
        'Word2vec + averaged with top morphemic F1 and frequency': embs_avg_f1_freq,
        'Word2vec + averaged with top morphemic F1 and probability': embs_avg_f1_prob}.items():
        # получаем эмбеддинги на основе однокоренных слов
        
        evaluate(new_model, model_name, 'CNN', corpus,
                 word_sim_datasets_tagged, new_words, embeddings)
                                
    del model_w2v, model_fasttext, new_model, data_w2v_cnn, data_w2v_morfessor, data_rare_words_cnn, data_rare_words_morfessor

# %%
models = {'word2vec':
                {'Tayga': 'http://vectors.nlpl.eu/repository/20/185.zip',
                'RNC': 'http://vectors.nlpl.eu/repository/20/180.zip',
                'Araneum': 'https://rusvectores.org/static/models/rusvectores4/araneum/araneum_upos_skipgram_300_2_2018.vec.gz'},
          'fasttext':
                {'Tayga': 'http://vectors.nlpl.eu/repository/20/187.zip',
                 'RNC': 'http://vectors.nlpl.eu/repository/20/181.zip',
                 'Araneum': 'https://rusvectores.org/static/models/rusvectores4/fasttext/araneum_none_fasttextcbow_300_5_2018.tgz'}}

# %%
affixes = []

for filename in {'endings.txt', 'interfixes.txt', 'postfixes.txt', 'prefixes.txt',
                 'suffixes_derivational.txt', 'suffixes_inflectional.txt'}:
    with open('MorphemicEmbeddings/MorphLists/'+filename, encoding='windows-1251') as f:
        data = f.read().split('\n')
        for affix in data:
            if '(' in affix:
                affix = affix.split('(')[0]
            affixes.append(affix)
affixes.append('-')
affixes = set(affixes)

# %%
word_sim_datasets = ['rare_multimorphemic.tsv', 'ae-test.csv', 
        'ae2-test.csv', 'hj-test.csv', 'rt-test.csv']
word_sim_datasets_tagged = ['{}_tagged.{}'.format(*dataset_name.split('.'))
        for dataset_name in word_sim_datasets]
        
words_for_most_similar = {'rare_multimorphemic_tagged.tsv':
        ['восемьсотпятидесятилетие_NOUN', 'древневерхненемецкий_ADJ',
        'камнесамоцветный_ADJ', 'раннеперестроечный_ADJ',
        'шумозаградительный_ADJ', 'биокибернетик_NOUN']}

# %%
wordlist_rare_multimorphemic = tag_word_simimilarity_data('rare_multimorphemic.tsv')
wordlist_aetest = tag_word_simimilarity_data('ae-test.csv')
wordlist_ae2test = tag_word_simimilarity_data('ae2-test.csv')
wordlist_hjtest = tag_word_simimilarity_data('hj-test.csv')
wordlist_rttest = tag_word_simimilarity_data('rt-test.csv')

rare_words = {'rare_multimorphemic_tagged.tsv': wordlist_rare_multimorphemic,
              'ae-test_tagged.csv': wordlist_aetest, 'ae2-test_tagged.csv': wordlist_ae2test,
              'hj-test_tagged.csv': wordlist_hjtest, 'rt-test_tagged.csv': wordlist_rttest}
              
all_wordlists_similarity = set(wordlist_rare_multimorphemic + wordlist_aetest +
        wordlist_ae2test + wordlist_hjtest + wordlist_rttest)

# %%
for corpus in 'RNC', 'Araneum', 'Tayga':
    experiment_for_one_corpus(corpus)
# Out:
# Downloading word2vec model (RNC)...
# --2020-07-15 19:46:49--  http://vectors.nlpl.eu/repository/20/180.zip
# Resolving vectors.nlpl.eu (vectors.nlpl.eu)... 129.240.189.225
# Connecting to vectors.nlpl.eu (vectors.nlpl.eu)|129.240.189.225|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 484452317 (462M) [application/zip]
# Saving to: ‘180.zip’
#
# 180.zip             100%[===================>] 462.01M  22.9MB/s    in 25s
#
# 2020-07-15 19:47:15 (18.2 MB/s) - ‘180.zip’ saved [484452317/484452317]
#
# Archive:  180.zip
#   inflating: word2vecRNC/meta.json
#   inflating: word2vecRNC/model.bin
#   inflating: word2vecRNC/model.txt
#   inflating: word2vecRNC/README
# Loading word2vec model (RNC)...
# Saving word2vec_RNC_vocab for morphemic analysis...
# Segmenting word2vec_RNC_vocab into morphemes with Morfessor model...
# Creating configuration file for CNN model...
# Segmenting word2vec_RNC_vocab into morphemes with CNN model...
# Using TensorFlow backend.
# 2020-07-15 19:48:39.470186: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 166
# 76
# 11636
# 2807
# 12423
# 2872
# 324
# 98
# 32
# 14
# 16
# 12
# 11822
# 2839
# 2020-07-15 19:48:42.258335: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-15 19:48:42.261515: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-15 19:48:42.261558: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (9e79c64349a0): /proc/driver/nvidia/version does not exist
# 2020-07-15 19:48:42.269325: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-07-15 19:48:42.269561: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x271ad80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-15 19:48:42.269601: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# symbol_inputs (InputLayer)      (None, None)         0
# __________________________________________________________________________________________________
# context_inputs (InputLayer)     (None, None, 15)     0
# __________________________________________________________________________________________________
# symbol_embeddings (Lambda)      (None, None, 37)     0           symbol_inputs[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 15)     0           context_inputs[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, 52)     0           symbol_embeddings[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, None, 240)    62640       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, None, 240)    0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, None, 240)    288240      dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, None, 240)    0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, None, 240)    288240      dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, None, 240)    0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, None, 240)    288240      dropout_4[0][0]
# __________________________________________________________________________________________________
# pre_output (TimeDistributed)    (None, None, 64)     15424       conv1d_4[0][0]
# __________________________________________________________________________________________________
# output (TimeDistributed)        (None, None, 25)     1625        pre_output[0][0]
# ==================================================================================================
# Total params: 944,409
# Trainable params: 944,409
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Processing morphemes for bucket length 7
# Processing morphemes for bucket length 7 finished
# Processing morphemes for bucket length 8
# Processing morphemes for bucket length 8 finished
# Processing morphemes for bucket length 9
# Processing morphemes for bucket length 9 finished
# Processing morphemes for bucket length 10
# Processing morphemes for bucket length 10 finished
# Processing morphemes for bucket length 11
# Processing morphemes for bucket length 11 finished
# Processing morphemes for bucket length 12
# Processing morphemes for bucket length 12 finished
# Processing morphemes for bucket length 13
# Processing morphemes for bucket length 13 finished
# Processing morphemes for bucket length 14
# Processing morphemes for bucket length 14 finished
# Processing morphemes for bucket length 33
# Processing morphemes for bucket length 33 finished
# Bucket 1 predicting
# Bucket 2 predicting
# Bucket 3 predicting
# Bucket 4 predicting
# Bucket 5 predicting
# Bucket 6 predicting
# Bucket 7 predicting
# Bucket 8 predicting
# Bucket 9 predicting
# MorphemicEmbeddings/NeuralMorphSegm/neural_morph_segm.py:805: RuntimeWarning: divide by zero encountered in log
#   curr_costs[state] = costs[-1][prev_state] - np.log(probs[i+1,state])
# 1000 words decoded
# 2000 words decoded
# 3000 words decoded
# 4000 words decoded
# 5000 words decoded
# 6000 words decoded
# 7000 words decoded
# 8000 words decoded
# 9000 words decoded
# 10000 words decoded
# 11000 words decoded
# 12000 words decoded
# 13000 words decoded
# 14000 words decoded
# 15000 words decoded
# 16000 words decoded
# 17000 words decoded
# 18000 words decoded
# 19000 words decoded
# 20000 words decoded
# 21000 words decoded
# 22000 words decoded
# 23000 words decoded
# 24000 words decoded
# 25000 words decoded
# 26000 words decoded
# 27000 words decoded
# 28000 words decoded
# 29000 words decoded
# 30000 words decoded
# 31000 words decoded
# 32000 words decoded
# 33000 words decoded
# 34000 words decoded
# 35000 words decoded
# 36000 words decoded
# 37000 words decoded
# 38000 words decoded
# 39000 words decoded
# 40000 words decoded
# 41000 words decoded
# 42000 words decoded
# 43000 words decoded
# 44000 words decoded
# 45000 words decoded
# 46000 words decoded
# 47000 words decoded
# 48000 words decoded
# 49000 words decoded
# 50000 words decoded
# 51000 words decoded
# 52000 words decoded
# 53000 words decoded
# 54000 words decoded
# 55000 words decoded
# 56000 words decoded
# 57000 words decoded
# 58000 words decoded
# 59000 words decoded
# 60000 words decoded
# 61000 words decoded
# 62000 words decoded
# 63000 words decoded
# 64000 words decoded
# 65000 words decoded
# 66000 words decoded
# 67000 words decoded
# 68000 words decoded
# 69000 words decoded
# 70000 words decoded
# 71000 words decoded
# 72000 words decoded
# 73000 words decoded
# 74000 words decoded
# 75000 words decoded
# 76000 words decoded
# 77000 words decoded
# 78000 words decoded
# 79000 words decoded
# 80000 words decoded
# 81000 words decoded
# 82000 words decoded
# 83000 words decoded
# 84000 words decoded
# 85000 words decoded
# 86000 words decoded
# 87000 words decoded
# 88000 words decoded
# 89000 words decoded
# 90000 words decoded
# 91000 words decoded
# 92000 words decoded
# 93000 words decoded
# 94000 words decoded
# 95000 words decoded
# 96000 words decoded
# 97000 words decoded
# 98000 words decoded
# 99000 words decoded
# 100000 words decoded
# 101000 words decoded
# 102000 words decoded
# 103000 words decoded
# 104000 words decoded
# 105000 words decoded
# 106000 words decoded
# 107000 words decoded
# 108000 words decoded
# 109000 words decoded
# 110000 words decoded
# 111000 words decoded
# 112000 words decoded
# 113000 words decoded
# 114000 words decoded
# 115000 words decoded
# 116000 words decoded
# 117000 words decoded
# 118000 words decoded
# 119000 words decoded
# 120000 words decoded
# 121000 words decoded
# 122000 words decoded
# 123000 words decoded
# 124000 words decoded
# 125000 words decoded
# 126000 words decoded
# 127000 words decoded
# 128000 words decoded
# 129000 words decoded
# 130000 words decoded
# 131000 words decoded
# 132000 words decoded
# 133000 words decoded
# 134000 words decoded
# 135000 words decoded
# 136000 words decoded
# 137000 words decoded
# 138000 words decoded
# 139000 words decoded
# 140000 words decoded
# 141000 words decoded
# 142000 words decoded
# 143000 words decoded
# 144000 words decoded
# 145000 words decoded
# 146000 words decoded
# 147000 words decoded
# 148000 words decoded
# 149000 words decoded
# 150000 words decoded
# 151000 words decoded
# 152000 words decoded
# 153000 words decoded
# 154000 words decoded
# 155000 words decoded
# 156000 words decoded
# 157000 words decoded
# 158000 words decoded
# 159000 words decoded
# 160000 words decoded
# 161000 words decoded
# 162000 words decoded
# 163000 words decoded
# 164000 words decoded
# 165000 words decoded
# 166000 words decoded
# 167000 words decoded
# 168000 words decoded
# 169000 words decoded
# 170000 words decoded
# 171000 words decoded
# 172000 words decoded
# 173000 words decoded
# Saving rare_words_RNC for morphemic analysis...
# Segmenting rare_words_RNC into morphemes with Morfessor model...
# Creating configuration file for CNN model...
# Segmenting rare_words_RNC into morphemes with CNN model...
# Using TensorFlow backend.
# 2020-07-15 19:56:35.659029: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 166
# 76
# 11636
# 2807
# 12423
# 2872
# 324
# 98
# 32
# 14
# 16
# 12
# 11822
# 2839
# 2020-07-15 19:56:38.160134: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-15 19:56:38.163389: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-15 19:56:38.163430: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (9e79c64349a0): /proc/driver/nvidia/version does not exist
# 2020-07-15 19:56:38.170159: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-07-15 19:56:38.170416: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2828d80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-15 19:56:38.170464: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# symbol_inputs (InputLayer)      (None, None)         0
# __________________________________________________________________________________________________
# context_inputs (InputLayer)     (None, None, 15)     0
# __________________________________________________________________________________________________
# symbol_embeddings (Lambda)      (None, None, 37)     0           symbol_inputs[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 15)     0           context_inputs[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, 52)     0           symbol_embeddings[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, None, 240)    62640       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, None, 240)    0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, None, 240)    288240      dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, None, 240)    0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, None, 240)    288240      dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, None, 240)    0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, None, 240)    288240      dropout_4[0][0]
# __________________________________________________________________________________________________
# pre_output (TimeDistributed)    (None, None, 64)     15424       conv1d_4[0][0]
# __________________________________________________________________________________________________
# output (TimeDistributed)        (None, None, 25)     1625        pre_output[0][0]
# ==================================================================================================
# Total params: 944,409
# Trainable params: 944,409
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Processing morphemes for bucket length 7
# Processing morphemes for bucket length 7 finished
# Processing morphemes for bucket length 8
# Processing morphemes for bucket length 8 finished
# Processing morphemes for bucket length 9
# Processing morphemes for bucket length 9 finished
# Processing morphemes for bucket length 10
# Processing morphemes for bucket length 10 finished
# Processing morphemes for bucket length 11
# Processing morphemes for bucket length 11 finished
# Processing morphemes for bucket length 12
# Processing morphemes for bucket length 12 finished
# Processing morphemes for bucket length 14
# Processing morphemes for bucket length 14 finished
# Processing morphemes for bucket length 16
# Processing morphemes for bucket length 16 finished
# Processing morphemes for bucket length 27
# Processing morphemes for bucket length 27 finished
# Bucket 1 predicting
# Bucket 2 predicting
# Bucket 3 predicting
# Bucket 4 predicting
# Bucket 5 predicting
# Bucket 6 predicting
# Bucket 7 predicting
# Bucket 8 predicting
# Bucket 9 predicting
# MorphemicEmbeddings/NeuralMorphSegm/neural_morph_segm.py:805: RuntimeWarning: divide by zero encountered in log
#   curr_costs[state] = costs[-1][prev_state] - np.log(probs[i+1,state])
# 1000 words decoded
# 2000 words decoded
# Downloading fasttext model (RNC)...
# --2020-07-15 19:56:49--  http://vectors.nlpl.eu/repository/20/181.zip
# Resolving vectors.nlpl.eu (vectors.nlpl.eu)... 129.240.189.225
# Connecting to vectors.nlpl.eu (vectors.nlpl.eu)|129.240.189.225|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2622716250 (2.4G) [application/zip]
# Saving to: ‘181.zip’
#
# 181.zip             100%[===================>]   2.44G  23.0MB/s    in 1m 54s
#
# 2020-07-15 19:58:44 (21.9 MB/s) - ‘181.zip’ saved [2622716250/2622716250]
#
# Archive:  181.zip
#   inflating: fasttextRNC/meta.json
#   inflating: fasttextRNC/model.model
#   inflating: fasttextRNC/model.model.vectors_ngrams.npy
#   inflating: fasttextRNC/model.model.vectors.npy
#   inflating: fasttextRNC/model.model.vectors_vocab.npy
#   inflating: fasttextRNC/README
# Loading fasttext model (RNC)...
#
# EVALUATING ON SEMANTIC SIMILARITY TASK
#
# Word2vec baseline (corpus: RNC, morphemic_model: None)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.3402
# p-value: 4.0992e-04
# OOV-pairs ratio: 0.4712
# ----------------------------------------------------------------------------------------------------
#
# Word2vec baseline (corpus: RNC, morphemic_model: None)
# ae-test_tagged
# Spearman correlation for human annotation: 0.3354
# p-value: 1.6650e-52
# OOV-pairs ratio: 0.2312
# ----------------------------------------------------------------------------------------------------
#
# Word2vec baseline (corpus: RNC, morphemic_model: None)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.7130
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.1086
# ----------------------------------------------------------------------------------------------------
#
# Word2vec baseline (corpus: RNC, morphemic_model: None)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6086
# p-value: 5.0945e-35
# OOV-pairs ratio: 0.0452
# ----------------------------------------------------------------------------------------------------
#
# Word2vec baseline (corpus: RNC, morphemic_model: None)
# rt-test_tagged
# Spearman correlation for human annotation: 0.4984
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.2266
# ----------------------------------------------------------------------------------------------------
#
# Word2vec random_vector4unknown (corpus: RNC, morphemic_model: None)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.4386
# p-value: 3.2006e-06
# OOV-pairs ratio: 0.0000
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# диспропорциональность_NOUN	0.7887
# биокибернетик_NOUN	0.7784
# ханты-мансийск_NOUN	0.7758
# полиизобутилен_NOUN	0.7732
# горношахтный_ADJ	0.772
# бессквозняковый_ADJ	0.7681
# асфальтобетонный_ADJ	0.7653
# франкфурт_NOUN	0.7625
# тетраэтилсвинец_NOUN	0.7601
# камнесамоцветный_ADJ	0.7593
#
# Words similar to древневерхненемецкий_ADJ:
# взаимозаменяемый_ADJ	0.7864
# эластокинематический_ADJ	0.7812
# центрально-черноземный_ADJ	0.7801
# шумозаградительный_ADJ	0.7693
# грузино-абхазский_ADJ	0.7664
# франкфурт_NOUN	0.7657
# гражданско-процессуальный_ADJ	0.764
# исправительно-трудовой_ADJ	0.7639
# легкоусвояемый_ADJ	0.7639
# склеропластика_NOUN	0.7572
#
# Words similar to камнесамоцветный_ADJ:
# неистрепанный_VERB	0.7816
# горношахтный_ADJ	0.781
# диспропорциональность_NOUN	0.7794
# электронно-механический_ADJ	0.7735
# грузино-абхазский_ADJ	0.7725
# безветреный_ADJ	0.7706
# валяносапожник_NOUN	0.7703
# детоталитаризация_NOUN	0.7687
# морально-нравственный_ADJ	0.7681
# полиизобутилен_NOUN	0.7672
#
# Words similar to раннеперестроечный_ADJ:
# асфальтобетонный_ADJ	0.7629
# диспропорциональность_NOUN	0.7619
# шумозаградительный_ADJ	0.7577
# уголовно-процессуальный_ADJ	0.7572
# горношахтный_ADJ	0.7553
# эластокинематический_ADJ	0.7531
# коксующийся_VERB	0.7496
# неизбирабельный_ADJ	0.7489
# валяносапожник_NOUN	0.7479
# необуржуазный_ADJ	0.7468
#
# Words similar to шумозаградительный_ADJ:
# эластокинематический_ADJ	0.7822
# древневерхненемецкий_ADJ	0.7693
# легкоусвояемый_ADJ	0.7683
# взаимозаменяемый_ADJ	0.7655
# полиизобутилен_NOUN	0.7652
# конкуретноспособность_NOUN	0.7618
# тетраэтилсвинец_NOUN	0.7592
# авиационно-космический_ADJ	0.759
# диспропорциональность_NOUN	0.7585
# полураспавшийся_VERB	0.7581
#
# Words similar to биокибернетик_NOUN:
# диспропорциональность_NOUN	0.7895
# грузино-абхазский_ADJ	0.7884
# непропорциональность_NOUN	0.7847
# неистрепанный_VERB	0.7843
# полиизобутилен_NOUN	0.7835
# нормальненько_ADV	0.7824
# бессквозняковый_ADJ	0.7821
# уголовно-процессуальный_ADJ	0.7809
# коксующийся_VERB	0.7792
# восемьсотпятидесятилетие_NOUN	0.7784
# ----------------------------------------------------------------------------------------------------
#
# Word2vec random_vector4unknown (corpus: RNC, morphemic_model: None)
# ae-test_tagged
# Spearman correlation for human annotation: 0.2803
# p-value: 1.4885e-36
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# Word2vec random_vector4unknown (corpus: RNC, morphemic_model: None)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.7102
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# Word2vec random_vector4unknown (corpus: RNC, morphemic_model: None)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6107
# p-value: 2.5501e-35
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# Word2vec random_vector4unknown (corpus: RNC, morphemic_model: None)
# rt-test_tagged
# Spearman correlation for human annotation: 0.5026
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# Word2vec random_similarity4unknown (corpus: RNC, morphemic_model: None)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.4574
# p-value: 1.0566e-06
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# Word2vec random_similarity4unknown (corpus: RNC, morphemic_model: None)
# ae-test_tagged
# Spearman correlation for human annotation: 0.6425
# p-value: 1.4270e-227
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# Word2vec random_similarity4unknown (corpus: RNC, morphemic_model: None)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.6932
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# Word2vec random_similarity4unknown (corpus: RNC, morphemic_model: None)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6383
# p-value: 2.2067e-39
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# Word2vec random_similarity4unknown (corpus: RNC, morphemic_model: None)
# rt-test_tagged
# Spearman correlation for human annotation: 0.4526
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# FastText (corpus: RNC, morphemic_model: None)
# rare_multimorphemic
# Spearman correlation for human annotation: 0.7265
# p-value: 2.5812e-18
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# FastText (corpus: RNC, morphemic_model: None)
# ae-test
# Spearman correlation for human annotation: 0.6259
# p-value: 8.0484e-213
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# FastText (corpus: RNC, morphemic_model: None)
# ae2-test
# Spearman correlation for human annotation: 0.7970
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# FastText (corpus: RNC, morphemic_model: None)
# hj-test
# Spearman correlation for human annotation: 0.7143
# p-value: 3.0105e-53
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
#
# FastText (corpus: RNC, morphemic_model: None)
# rt-test
# Spearman correlation for human annotation: 0.6905
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0000
# ----------------------------------------------------------------------------------------------------
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in true_divide
# Word2vec + averaged (corpus: RNC, morphemic_model: Morfessor)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.6380
# p-value: 3.2389e-13
# OOV-pairs ratio: 0.0000
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# пролететь_VERB	0.5966
# приземлиться_VERB	0.5315
# взмыть_VERB	0.5245
# летевать_VERB	0.5181
# пролетать_VERB	0.5112
# перелететь_VERB	0.5073
# взмывать_VERB	0.4993
# подлетать_VERB	0.4971
# зависнуть_NOUN	0.4959
# полураспавшийся_VERB	0.4955
#
# Words similar to древневерхненемецкий_ADJ:
# вверх_ADV	0.5767
# вершина_NOUN	0.5449
# центрально-черноземный_ADJ	0.5213
# полуразложившийся_VERB	0.5112
# вверху_ADV	0.5087
# отлогой_NOUN	0.5069
# сверху_ADV	0.5062
# гора_NOUN	0.5036
# верх_NOUN	0.5027
# кверху_ADV	0.5016
#
# Words similar to камнесамоцветный_ADJ:
# самозатачивающийся_ADJ	0.8902
# самоутверждение_NOUN	0.5473
# стремление_NOUN	0.5288
# бунтарство_NOUN	0.5134
# способный_ADJ	0.4892
# индивидуальность_NOUN	0.4816
# своеволие_NOUN	0.4778
# самосознание_NOUN	0.4743
# самобытность_NOUN	0.4741
# индивидуализм_NOUN	0.4683
#
# Words similar to раннеперестроечный_ADJ:
# строиться_NOUN	0.5852
# сооружаться_VERB	0.5532
# построить_VERB	0.5256
# строить_ADJ	0.5229
# центрально-черноземный_ADJ	0.5199
# перестроать_VERB	0.5091
# крупнопанельный_ADJ	0.5049
# строить_VERB	0.5031
# выстроить_VERB	0.5021
# полуразложившийся_VERB	0.4904
#
# Words similar to шумозаградительный_ADJ:
# центрально-черноземный_ADJ	0.5641
# овруч_PROPN	0.5034
# сумы_PROPN	0.5015
# стольный_ADJ	0.4923
# град_NOUN	0.4882
# раннеперестроечный_ADJ	0.4821
# славный_PROPN	0.4801
# лубна_ADJ	0.4783
# ржева_PROPN	0.4767
# город_NOUN	0.4695
#
# Words similar to биокибернетик_NOUN:
# гастроэнтеролог_NOUN	0.7882
# биологический_ADJ	0.7725
# биохимия_NOUN	0.743
# биолог_NOUN	0.7362
# биология_NOUN	0.7237
# биохимический_ADJ	0.702
# биохимик_NOUN	0.6968
# микробиологический_ADJ	0.6863
# генетика_NOUN	0.6622
# биотехнология_NOUN	0.6605
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged (corpus: RNC, morphemic_model: Morfessor)
# ae-test_tagged
# Spearman correlation for human annotation: 0.4972
# p-value: 2.5189e-122
# OOV-pairs ratio: 0.0123
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged (corpus: RNC, morphemic_model: Morfessor)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.7672
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0087
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged (corpus: RNC, morphemic_model: Morfessor)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6390
# p-value: 1.7007e-39
# OOV-pairs ratio: 0.0090
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged (corpus: RNC, morphemic_model: Morfessor)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6223
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0145
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + frequency weighted (corpus: RNC, morphemic_model: Morfessor)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.6205
# p-value: 2.1388e-12
# OOV-pairs ratio: 0.0000
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# лет_NOUN	0.8816
# лет_ADJ	0.6712
# лет_ADV	0.6622
# копеек_NOUN	0.6344
# лет-то_ADV	0.6204
# годочек_NOUN	0.6188
# секундтраница_NOUN	0.6083
# минут_NOUN	0.5981
# верста_INTJ	0.5935
# лет_VERB	0.5865
#
# Words similar to древневерхненемецкий_ADJ:
# вверх_ADV	0.8373
# сверху_ADV	0.7502
# вниз_ADV	0.7022
# кверху_ADV	0.6742
# отвесно_ADV	0.6079
# горизонтально_ADV	0.6057
# наклонно_ADV	0.5948
# наверх_ADV	0.5914
# снизу_ADV	0.5865
# вверху_ADV	0.5757
#
# Words similar to камнесамоцветный_ADJ:
# самозатачивающийся_ADJ	0.9886
# сам_PROPN	0.661
# сам_ADJ	0.6536
# сам_NOUN	0.5518
# сами-той_ADV	0.5239
# сами_ADJ	0.5207
# что_NOUN	0.4967
# сам_VERB	0.4913
# бог-то_ADV	0.4848
# сам-той_NOUN	0.4842
#
# Words similar to раннеперестроечный_ADJ:
# строительство_NOUN	0.7224
# реконструкция_NOUN	0.6238
# постройка_NOUN	0.5774
# строиться_NOUN	0.5761
# ранее_ADV	0.5675
# строить_VERB	0.5673
# строитель_NOUN	0.5667
# строиться_VERB	0.5483
# возведение_NOUN	0.5408
# капремонт_NOUN	0.5377
#
# Words similar to шумозаградительный_ADJ:
# шум_PROPN	0.7367
# шум_NOUN	0.6978
# гул_NOUN	0.6117
# грохот_NOUN	0.5697
# рокот_NOUN	0.5528
# многоголосый_ADJ	0.552
# канонада_PROPN	0.5334
# гомон_NOUN	0.5255
# град_NOUN	0.5234
# канонада_NOUN	0.5028
#
# Words similar to биокибернетик_NOUN:
# биология_NOUN	0.8159
# генетика_NOUN	0.6969
# биохимия_NOUN	0.6635
# биография_NOUN	0.6604
# биолог_NOUN	0.6559
# биологический_ADJ	0.6557
# эмбриология_NOUN	0.6308
# физиология_NOUN	0.6111
# гастроэнтеролог_NOUN	0.5912
# естествознание_NOUN	0.5885
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + frequency weighted (corpus: RNC, morphemic_model: Morfessor)
# ae-test_tagged
# Spearman correlation for human annotation: 0.4912
# p-value: 5.3902e-119
# OOV-pairs ratio: 0.0123
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + frequency weighted (corpus: RNC, morphemic_model: Morfessor)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.7517
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0087
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + frequency weighted (corpus: RNC, morphemic_model: Morfessor)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6384
# p-value: 2.0867e-39
# OOV-pairs ratio: 0.0090
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + frequency weighted (corpus: RNC, morphemic_model: Morfessor)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6066
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0145
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: RNC, morphemic_model: Morfessor)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.6903
# p-value: 5.1986e-16
# OOV-pairs ratio: 0.0000
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# восемь_NUM	0.7713
# семь_NUM	0.7629
# шесть_NUM	0.7502
# пять_NUM	0.7349
# двадцать_NUM	0.732
# девять_NUM	0.7279
# тридцать_NUM	0.7243
# семьдесят_NUM	0.713
# шестьдесят_NUM	0.7103
# пятьдесят_NUM	0.6962
#
# Words similar to древневерхненемецкий_ADJ:
# древний_ADJ	0.7046
# древность_NOUN	0.6508
# древнейший_ADJ	0.6195
# древнеегипетский_ADJ	0.5772
# поверхность_NOUN	0.5471
# древнегреческий_ADJ	0.5422
# шумерский_ADJ	0.5354
# письмена_NOUN	0.5317
# древний_NOUN	0.5231
# финикийский_ADJ	0.5224
#
# Words similar to камнесамоцветный_ADJ:
# цвет_NOUN	0.7015
# цветы_NOUN	0.6568
# цветок_NOUN	0.5951
# ирис_NOUN	0.5757
# роза_NOUN	0.5393
# цвт_NOUN	0.5351
# тюльпан_NOUN	0.5327
# цветочек_NOUN	0.525
# пурпурный_ADJ	0.5234
# бархатцы_NOUN	0.512
#
# Words similar to раннеперестроечный_ADJ:
# строительство_NOUN	0.5995
# неремонтопригодный_ADJ	0.5265
# реконструкция_NOUN	0.5138
# постройка_NOUN	0.4949
# ранее_ADV	0.4944
# капремонт_NOUN	0.4872
# дск_PROPN	0.4833
# рано_ADV	0.4831
# строитель_NOUN	0.4721
# строиться_NOUN	0.4618
#
# Words similar to шумозаградительный_ADJ:
# град_NOUN	0.6844
# град_PROPN	0.6149
# шум_PROPN	0.5991
# шум_NOUN	0.5762
# гул_NOUN	0.5085
# стольный_ADJ	0.4942
# канонада_PROPN	0.4936
# гром_ADJ	0.4935
# грохот_NOUN	0.487
# канонада_NOUN	0.4791
#
# Words similar to биокибернетик_NOUN:
# биология_NOUN	0.8285
# кибернетика_NOUN	0.7593
# биологический_ADJ	0.7222
# генетика_NOUN	0.7181
# биолог_NOUN	0.6525
# биохимия_NOUN	0.6416
# нейрофизиология_NOUN	0.6403
# бионика_NOUN	0.6216
# наука_NOUN	0.6203
# научный_ADJ	0.6167
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: RNC, morphemic_model: Morfessor)
# ae-test_tagged
# Spearman correlation for human annotation: 0.4856
# p-value: 5.8598e-116
# OOV-pairs ratio: 0.0123
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: RNC, morphemic_model: Morfessor)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.7500
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0087
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: RNC, morphemic_model: Morfessor)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6375
# p-value: 2.8755e-39
# OOV-pairs ratio: 0.0090
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: RNC, morphemic_model: Morfessor)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6082
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0145
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged (corpus: RNC, morphemic_model: CNN)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.6820
# p-value: 1.5739e-15
# OOV-pairs ratio: 0.0385
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# пролететь_VERB	0.6356
# пролетать_VERB	0.5682
# полет_VERB	0.5669
# летевать_VERB	0.5625
# приземлиться_VERB	0.5606
# перелететь_VERB	0.5536
# взмыть_VERB	0.5476
# взлететь_VERB	0.5424
# подлетать_VERB	0.5375
# перелть_NOUN	0.5283
#
# Words similar to древневерхненемецкий_ADJ:
# верхний_ADJ	0.5417
# вверх_ADV	0.5374
# древний_ADJ	0.5318
# конусообразный_ADJ	0.5256
# полуразложившийся_VERB	0.5202
# вершина_NOUN	0.5127
# остроконечный_ADJ	0.5105
# центрально-черноземный_ADJ	0.5086
# вверху_ADV	0.5019
# ступенчатый_ADJ	0.4927
#
# Words similar to камнесамоцветный_ADJ:
# самозатачивающийся_ADJ	0.9029
# самоутверждение_NOUN	0.6035
# стремление_NOUN	0.5586
# легкоусвояемый_ADJ	0.547
# индивидуальность_NOUN	0.5395
# бунтарство_NOUN	0.5253
# способный_ADJ	0.5246
# самобытность_NOUN	0.5209
# самосознание_NOUN	0.519
# самобытный_ADJ	0.5118
#
# Words similar to раннеперестроечный_ADJ:
# строить_VERB	0.7167
# строиться_NOUN	0.7077
# построить_VERB	0.6917
# сооружаться_VERB	0.6719
# строиться_VERB	0.6662
# строительство_NOUN	0.6558
# выстроить_VERB	0.6395
# постройка_NOUN	0.6358
# достраивать_VERB	0.6347
# строитель_NOUN	0.624
#
# Words similar to шумозаградительный_ADJ:
# центрально-черноземный_ADJ	0.5196
# шум_PROPN	0.4792
# прошуметь_VERB	0.4783
# воронцовский_ADJ	0.4599
# сумы_PROPN	0.4585
# шуметь_NOUN	0.4581
# зашуметь_VERB	0.4498
# многоголосый_ADJ	0.448
# славный_PROPN	0.4452
# аксайский_ADJ	0.4442
#
# Words similar to биокибернетик_NOUN:
# гастроэнтеролог_NOUN	0.7861
# биологический_ADJ	0.7739
# биохимия_NOUN	0.7469
# биолог_NOUN	0.736
# биология_NOUN	0.7294
# биохимический_ADJ	0.6994
# биохимик_NOUN	0.6989
# микробиологический_ADJ	0.6805
# генетика_NOUN	0.6671
# биофизический_ADJ	0.6575
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged (corpus: RNC, morphemic_model: CNN)
# ae-test_tagged
# Spearman correlation for human annotation: 0.4961
# p-value: 9.9152e-122
# OOV-pairs ratio: 0.0272
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged (corpus: RNC, morphemic_model: CNN)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.7769
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0087
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged (corpus: RNC, morphemic_model: CNN)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6681
# p-value: 2.8278e-44
# OOV-pairs ratio: 0.0060
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged (corpus: RNC, morphemic_model: CNN)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6324
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0197
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + frequency weighted (corpus: RNC, morphemic_model: CNN)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.6215
# p-value: 1.9283e-12
# OOV-pairs ratio: 0.0385
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# лет_NOUN	0.8909
# лет_ADJ	0.6649
# лет_ADV	0.6559
# копеек_NOUN	0.6262
# лет-то_ADV	0.6222
# годочек_NOUN	0.6137
# секундтраница_NOUN	0.6069
# минут_NOUN	0.5985
# верста_INTJ	0.5881
# летинский_ADJ	0.5836
#
# Words similar to древневерхненемецкий_ADJ:
# вверх_ADV	0.8325
# сверху_ADV	0.755
# вниз_ADV	0.7073
# кверху_ADV	0.6708
# верхний_ADJ	0.6337
# горизонтально_ADV	0.6283
# наклонно_ADV	0.6191
# снизу_ADV	0.6013
# отвесно_ADV	0.5996
# наверх_ADV	0.5943
#
# Words similar to камнесамоцветный_ADJ:
# самозатачивающийся_ADJ	0.9871
# сам_ADJ	0.6779
# сам_PROPN	0.66
# сам_NOUN	0.5395
# истинно_NOUN	0.4714
# сами-той_ADV	0.468
# сами_ADJ	0.4631
# сама_ADJ	0.4572
# что_NOUN	0.4565
# сам_VERB	0.4539
#
# Words similar to раннеперестроечный_ADJ:
# строительство_NOUN	0.8526
# строить_VERB	0.7739
# построить_VERB	0.7155
# строиться_NOUN	0.7094
# строитель_NOUN	0.6779
# постройка_NOUN	0.6739
# строиться_VERB	0.6684
# сооружаться_VERB	0.6626
# возведение_NOUN	0.6549
# сооружение_NOUN	0.6353
#
# Words similar to шумозаградительный_ADJ:
# шум_PROPN	0.7714
# шум_NOUN	0.7702
# гул_NOUN	0.6407
# грохот_NOUN	0.5977
# рокот_NOUN	0.5896
# многоголосый_ADJ	0.5802
# гомон_NOUN	0.5742
# гам_NOUN	0.5612
# рев_NOUN	0.5415
# немолчный_ADJ	0.5365
#
# Words similar to биокибернетик_NOUN:
# биология_NOUN	0.8155
# генетика_NOUN	0.6957
# биография_NOUN	0.6629
# биохимия_NOUN	0.6615
# биологический_ADJ	0.6548
# биолог_NOUN	0.6529
# эмбриология_NOUN	0.6297
# гастроэнтеролог_NOUN	0.6133
# физиология_NOUN	0.6101
# естествознание_NOUN	0.5886
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + frequency weighted (corpus: RNC, morphemic_model: CNN)
# ae-test_tagged
# Spearman correlation for human annotation: 0.4962
# p-value: 8.3591e-122
# OOV-pairs ratio: 0.0272
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + frequency weighted (corpus: RNC, morphemic_model: CNN)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.7731
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0087
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + frequency weighted (corpus: RNC, morphemic_model: CNN)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6469
# p-value: 9.7264e-41
# OOV-pairs ratio: 0.0060
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + frequency weighted (corpus: RNC, morphemic_model: CNN)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6113
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0197
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + probability weighted (corpus: RNC, morphemic_model: CNN)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.6810
# p-value: 1.7965e-15
# OOV-pairs ratio: 0.0385
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# пролететь_VERB	0.6204
# пролетать_VERB	0.5507
# полет_VERB	0.5507
# приземлиться_VERB	0.5442
# летевать_VERB	0.5441
# перелететь_VERB	0.5398
# взмыть_VERB	0.5361
# взлететь_VERB	0.5246
# перелть_NOUN	0.5219
# подлетать_VERB	0.5179
#
# Words similar to древневерхненемецкий_ADJ:
# древний_ADJ	0.5972
# древнеегипетский_ADJ	0.5366
# верхний_ADJ	0.5334
# шумерский_ADJ	0.533
# конусообразный_ADJ	0.5188
# вершина_NOUN	0.5139
# древность_NOUN	0.5128
# остроконечный_ADJ	0.5114
# древнейший_ADJ	0.5084
# ступенчатый_ADJ	0.5067
#
# Words similar to камнесамоцветный_ADJ:
# самозатачивающийся_ADJ	0.8958
# самоутверждение_NOUN	0.6002
# стремление_NOUN	0.5559
# легкоусвояемый_ADJ	0.5553
# индивидуальность_NOUN	0.5376
# бунтарство_NOUN	0.5237
# способный_ADJ	0.5213
# самобытность_NOUN	0.519
# самосознание_NOUN	0.5168
# самобытный_ADJ	0.5141
#
# Words similar to раннеперестроечный_ADJ:
# строить_VERB	0.7142
# строиться_NOUN	0.7039
# построить_VERB	0.693
# сооружаться_VERB	0.6752
# строиться_VERB	0.6531
# строительство_NOUN	0.6495
# выстроить_VERB	0.6425
# достраивать_VERB	0.6363
# постройка_NOUN	0.6306
# спроектировать_VERB	0.6283
#
# Words similar to шумозаградительный_ADJ:
# центрально-черноземный_ADJ	0.513
# шум_PROPN	0.4898
# прошуметь_VERB	0.4887
# воронцовский_ADJ	0.4605
# шуметь_NOUN	0.4584
# зашуметь_VERB	0.4532
# сумы_PROPN	0.4502
# многоголосый_ADJ	0.45
# славный_PROPN	0.4481
# стольный_ADJ	0.4474
#
# Words similar to биокибернетик_NOUN:
# биологический_ADJ	0.7841
# гастроэнтеролог_NOUN	0.7791
# биохимия_NOUN	0.7574
# биолог_NOUN	0.7398
# биология_NOUN	0.7302
# биохимический_ADJ	0.7147
# биохимик_NOUN	0.7039
# микробиологический_ADJ	0.6997
# генетика_NOUN	0.6676
# биотехнология_NOUN	0.6666
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + probability weighted (corpus: RNC, morphemic_model: CNN)
# ae-test_tagged
# Spearman correlation for human annotation: 0.4940
# p-value: 1.4828e-120
# OOV-pairs ratio: 0.0272
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + probability weighted (corpus: RNC, morphemic_model: CNN)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.7769
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0087
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + probability weighted (corpus: RNC, morphemic_model: CNN)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6689
# p-value: 2.0207e-44
# OOV-pairs ratio: 0.0060
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + probability weighted (corpus: RNC, morphemic_model: CNN)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6330
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0197
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: RNC, morphemic_model: CNN)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.6899
# p-value: 5.5011e-16
# OOV-pairs ratio: 0.0385
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# двадцать_NUM	0.8049
# тридцать_NUM	0.7809
# восемь_NUM	0.7758
# сорока_NUM	0.7679
# семьдесят_NUM	0.767
# семь_NUM	0.7663
# пять_NUM	0.7534
# шесть_NUM	0.752
# шестьдесят_NUM	0.7484
# пятьдесят_NUM	0.7473
#
# Words similar to древневерхненемецкий_ADJ:
# древний_ADJ	0.5751
# поверхность_NOUN	0.5343
# древнейший_ADJ	0.5266
# вверх_ADV	0.5101
# запад_NOUN	0.5007
# сверху_ADV	0.4996
# конус_NOUN	0.4888
# камень_NOUN	0.4841
# древность_NOUN	0.4808
# древнеегипетский_ADJ	0.4758
#
# Words similar to камнесамоцветный_ADJ:
# цвет_NOUN	0.7361
# цветы_NOUN	0.7045
# цветок_NOUN	0.6407
# ирис_NOUN	0.606
# роза_NOUN	0.5825
# цветочек_NOUN	0.5604
# цвт_NOUN	0.5577
# тюльпан_NOUN	0.555
# лилия_NOUN	0.5467
# незабудка_NOUN	0.5419
#
# Words similar to раннеперестроечный_ADJ:
# строительство_NOUN	0.8851
# построить_VERB	0.7637
# строить_VERB	0.7383
# строиться_NOUN	0.7132
# возведение_NOUN	0.6929
# строитель_NOUN	0.6878
# сооружаться_VERB	0.6862
# реконструкция_NOUN	0.6695
# постройка_NOUN	0.6589
# сооружение_NOUN	0.6485
#
# Words similar to шумозаградительный_ADJ:
# шум_NOUN	0.6282
# шум_PROPN	0.6025
# град_NOUN	0.6019
# гул_NOUN	0.542
# град_PROPN	0.532
# гром_ADJ	0.5294
# грохот_NOUN	0.5186
# многоголосый_ADJ	0.5167
# гам_NOUN	0.5162
# гром_NOUN	0.5052
#
# Words similar to биокибернетик_NOUN:
# биология_NOUN	0.8285
# кибернетика_NOUN	0.7593
# биологический_ADJ	0.7222
# генетика_NOUN	0.7181
# биолог_NOUN	0.6525
# биохимия_NOUN	0.6416
# нейрофизиология_NOUN	0.6403
# бионика_NOUN	0.6216
# наука_NOUN	0.6203
# научный_ADJ	0.6167
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: RNC, morphemic_model: CNN)
# ae-test_tagged
# Spearman correlation for human annotation: 0.4849
# p-value: 1.2646e-115
# OOV-pairs ratio: 0.0272
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: RNC, morphemic_model: CNN)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.7752
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0087
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: RNC, morphemic_model: CNN)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6618
# p-value: 3.3656e-43
# OOV-pairs ratio: 0.0060
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: RNC, morphemic_model: CNN)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6190
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0197
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top probabilities (corpus: RNC, morphemic_model: CNN)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.6610
# p-value: 2.2447e-14
# OOV-pairs ratio: 0.0385
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# восемь_NUM	0.7609
# семь_NUM	0.7475
# шесть_NUM	0.7376
# девять_NUM	0.7318
# восемь_ADV	0.7204
# восемь_NOUN	0.7094
# -восемь_NUM	0.7077
# годочек_NOUN	0.6999
# пять_NUM	0.6921
# лет_ADV	0.6907
#
# Words similar to древневерхненемецкий_ADJ:
# древнегреческий_ADJ	0.6158
# древнерусский_ADJ	0.5984
# шумерский_ADJ	0.5777
# древний_ADJ	0.5699
# древнеегипетский_ADJ	0.5412
# древнеславянский_ADJ	0.5346
# древнееврейский_ADJ	0.5268
# греческий_ADJ	0.5237
# античный_ADJ	0.5233
# хеттский_ADJ	0.5166
#
# Words similar to камнесамоцветный_ADJ:
# самозатачивающийся_ADJ	0.7573
# самоуправление_NOUN	0.6983
# самоорганизация_NOUN	0.5865
# расцветать_VERB	0.4849
# хозяйствование_NOUN	0.4578
# демократия_NOUN	0.4545
# развитие_NOUN	0.4484
# организация_NOUN	0.4361
# землепользование_NOUN	0.4352
# демократизация_NOUN	0.4305
#
# Words similar to раннеперестроечный_ADJ:
# расстроить_VERB	0.7079
# расстроиться_VERB	0.6673
# выстроить_VERB	0.6382
# расстраивать_VERB	0.564
# выстраивать_VERB	0.5396
# расшататься_VERB	0.5208
# выстроить_ADJ	0.4954
# построить_VERB	0.488
# расстроивать_VERB	0.4419
# строить_VERB	0.4251
#
# Words similar to шумозаградительный_ADJ:
# шум_NOUN	0.9026
# шум_PROPN	0.8821
# гул_NOUN	0.7084
# грохот_NOUN	0.6404
# гомон_NOUN	0.635
# рокот_NOUN	0.6329
# шумя_NOUN	0.6326
# гам_NOUN	0.622
# гвалт_NOUN	0.6212
# рев_NOUN	0.6009
#
# Words similar to биокибернетик_NOUN:
# кибернетика_NOUN	0.8127
# кибернетический_ADJ	0.7438
# биология_NOUN	0.6727
# биолог_NOUN	0.6553
# нейрофизиология_NOUN	0.6487
# биофизик_NOUN	0.6481
# бионика_NOUN	0.6453
# генетика_NOUN	0.6245
# биологический_ADJ	0.6168
# биохимия_NOUN	0.6155
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top probabilities (corpus: RNC, morphemic_model: CNN)
# ae-test_tagged
# Spearman correlation for human annotation: 0.4505
# p-value: 4.1536e-98
# OOV-pairs ratio: 0.0272
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top probabilities (corpus: RNC, morphemic_model: CNN)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.7695
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0087
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top probabilities (corpus: RNC, morphemic_model: CNN)
# hj-test_tagged
# Spearman correlation for human annotation: 0.6649
# p-value: 1.0062e-43
# OOV-pairs ratio: 0.0060
# ----------------------------------------------------------------------------------------------------
#
# ...
#
# Word2vec + frequency weighted (corpus: Tayga, morphemic_model: CNN)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6782
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0082
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + probability weighted (corpus: Tayga, morphemic_model: CNN)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.6844
# p-value: 1.1461e-15
# OOV-pairs ratio: 0.0385
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# неремонтопригодный_ADJ	0.7899
# полуразложившийся_VERB	0.7862
# полураспавшийся_VERB	0.7833
# полузамерзший_VERB	0.7764
# центрально-черноземный_ADJ	0.735
# авиационно-космический_ADJ	0.7258
# шумозаградительный_ADJ	0.7117
# горношахтный_ADJ	0.7066
# длиннобазный_ADJ	0.6626
# -колосися_NOUN	0.6607
#
# Words similar to древневерхненемецкий_ADJ:
# центрально-черноземный_ADJ	0.813
# полуразложившийся_VERB	0.7622
# полураспавшийся_VERB	0.723
# полузамерзший_VERB	0.7177
# общеправовой_ADJ	0.7009
# горношахтный_ADJ	0.6996
# шумозаградительный_ADJ	0.6913
# камнесамоцветный_ADJ	0.6897
# конституционно-правовой_ADJ	0.6801
# полиизобутилен_NOUN	0.6762
#
# Words similar to камнесамоцветный_ADJ:
# самозатачивающийся_ADJ	0.9775
# общеправовой_ADJ	0.8057
# исправительно-трудовой_ADJ	0.785
# легкоусвояемый_ADJ	0.7801
# центрально-черноземный_ADJ	0.7744
# полиизобутилен_NOUN	0.7742
# конституционно-правовой_ADJ	0.7608
# полуразложившийся_VERB	0.7544
# залогодержатель_NOUN	0.7472
# гражданско-процессуальный_ADJ	0.7294
#
# Words similar to раннеперестроечный_ADJ:
# общеправовой_ADJ	0.703
# центрально-черноземный_ADJ	0.6984
# шумозаградительный_ADJ	0.6886
# полиизобутилен_NOUN	0.6879
# исправительно-трудовой_ADJ	0.6877
# полуразложившийся_VERB	0.6713
# неремонтопригодный_ADJ	0.6519
# построить_VERB	0.6512
# камнесамоцветный_ADJ	0.6501
# конституционно-правовой_ADJ	0.6482
#
# Words similar to шумозаградительный_ADJ:
# центрально-черноземный_ADJ	0.8127
# горношахтный_ADJ	0.7634
# полуразложившийся_VERB	0.7354
# полураспавшийся_VERB	0.7227
# полузамерзший_VERB	0.7187
# восемьсотпятидесятилетие_NOUN	0.7117
# древневерхненемецкий_ADJ	0.6913
# раннеперестроечный_ADJ	0.6886
# полиизобутилен_NOUN	0.68
# исправительно-трудовой_ADJ	0.6788
#
# Words similar to биокибернетик_NOUN:
# залогодержатель_NOUN	0.8413
# полиизобутилен_NOUN	0.7799
# гидрокарбонатный_ADJ	0.7302
# биохимический_ADJ	0.7182
# электронно-механический_ADJ	0.7119
# морфогенетический_ADJ	0.7067
# биологический_ADJ	0.7049
# уголовно-процессуальный_ADJ	0.7043
# камнесамоцветный_ADJ	0.6867
# генный_ADJ	0.6845
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + probability weighted (corpus: Tayga, morphemic_model: CNN)
# ae-test_tagged
# Spearman correlation for human annotation: 0.6367
# p-value: 3.0121e-222
# OOV-pairs ratio: 0.0287
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + probability weighted (corpus: Tayga, morphemic_model: CNN)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.8271
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0017
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + probability weighted (corpus: Tayga, morphemic_model: CNN)
# hj-test_tagged
# Spearman correlation for human annotation: 0.7373
# p-value: 3.5854e-58
# OOV-pairs ratio: 0.0060
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + probability weighted (corpus: Tayga, morphemic_model: CNN)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6967
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0082
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: Tayga, morphemic_model: CNN)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.7202
# p-value: 6.9246e-18
# OOV-pairs ratio: 0.0385
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# тридцать_NUM	0.7806
# двадцать_NUM	0.7619
# пятьдесят_NUM	0.7581
# семьдесят_NUM	0.7531
# шестьдесят_NUM	0.7497
# тринадцать_NUM	0.7483
# восемнадцать_NUM	0.7475
# восемь_NUM	0.7378
# сорок_NUM	0.7319
# пять_NUM	0.7303
#
# Words similar to древневерхненемецкий_ADJ:
# древний_NOUN	0.6151
# древний_ADJ	0.6
# древний_ADV	0.5577
# древние_ADJ	0.5557
# древний_PROPN	0.5466
# -черноземя_VERB	0.5416
# вулсини_PROPN	0.5405
# http://www.proza.ru/2012/09/27/1573_NUM	0.5295
# вверх_ADV	0.5294
# возможностно_NOUN	0.5281
#
# Words similar to камнесамоцветный_ADJ:
# цвета_NOUN	0.6622
# цвет_NOUN	0.6555
# цвет_ADV	0.6355
# цвет_VERB	0.6299
# цвет_PROPN	0.6141
# самозатачивающийся_ADJ	0.5896
# древесностружечный_ADJ	0.5466
# тёмными_NOUN	0.5464
# цветной_NOUN	0.5164
# камень_NOUN	0.5151
#
# Words similar to раннеперестроечный_ADJ:
# построить_VERB	0.6798
# строительство_NOUN	0.6748
# строить_VERB	0.6407
# раннесредневековый_ADJ	0.6361
# построить_ADJ	0.6319
# раннефеодальный_ADJ	0.6186
# возведение_NOUN	0.6185
# раннехристианский_ADJ	0.6017
# строительство_PROPN	0.5988
# синташтинский_ADJ	0.5963
#
# Words similar to шумозаградительный_ADJ:
# шум_PROPN	0.7293
# шум_NOUN	0.7267
# шум_NUM	0.663
# гам_NOUN	0.633
# гул_NOUN	0.6127
# шум-г_NOUN	0.6103
# гомон_NOUN	0.5969
# гвалт_NOUN	0.5949
# гвалт_VERB	0.583
# шума_NOUN	0.5779
#
# Words similar to биокибернетик_NOUN:
# кибернетика_NOUN	0.7402
# биология_NOUN	0.6947
# инженерия_NOUN	0.6911
# генетика_NOUN	0.6837
# кибернетика_PROPN	0.6799
# биология_PROPN	0.6663
# социология_NOUN	0.6316
# синергетика_PROPN	0.6245
# кибернетический_ADJ	0.6225
# биофизик_NOUN	0.6211
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: Tayga, morphemic_model: CNN)
# ae-test_tagged
# Spearman correlation for human annotation: 0.5656
# p-value: 2.1230e-165
# OOV-pairs ratio: 0.0287
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: Tayga, morphemic_model: CNN)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.8258
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0017
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: Tayga, morphemic_model: CNN)
# hj-test_tagged
# Spearman correlation for human annotation: 0.7348
# p-value: 1.3786e-57
# OOV-pairs ratio: 0.0060
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top frequencies (corpus: Tayga, morphemic_model: CNN)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6792
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0082
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top probabilities (corpus: Tayga, morphemic_model: CNN)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.7272
# p-value: 2.3005e-18
# OOV-pairs ratio: 0.0385
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# восемь_NUM	0.6574
# пять_NUM	0.6534
# -восемь_NUM	0.6398
# -восемь_NOUN	0.639
# шесть_NUM	0.6368
# -шесть_NOUN	0.6257
# тринадцать_NUM	0.6157
# девять_NUM	0.6148
# тридцать_NUM	0.6135
# восемнадцать_NUM	0.6116
#
# Words similar to древневерхненемецкий_ADJ:
# онеметь_VERB	0.5964
# древнерусский_ADJ	0.5906
# древнегреческий_ADJ	0.5822
# http://www.proza.ru/2012/09/27/1573_NUM	0.5795
# http://www.proza.ru/2012/09/26/1191_NOUN	0.5725
# древнеславянский_ADJ	0.5603
# древнееврейский_ADJ	0.5539
# древнеегипетский_ADJ	0.5482
# шумерский_ADJ	0.5465
# санскритский_ADJ	0.5425
#
# Words similar to камнесамоцветный_ADJ:
# самозатачивающийся_ADJ	0.636
# -колосися_NOUN	0.5704
# до+амтериализуясь+в_NOUN	0.5584
# ширк-ширк_PROPN	0.5577
# самоорганизация_NOUN	0.526
# начал_ADJ	0.5246
# центрально-черноземный_ADJ	0.5234
# расцветиться_VERB	0.5193
# расцветать_VERB	0.5141
# самоуправление_NOUN	0.5111
#
# Words similar to раннеперестроечный_ADJ:
# раннесредневековый_ADJ	0.6491
# раннефеодальный_ADJ	0.6255
# раннехристианский_ADJ	0.6211
# эллинистический_ADJ	0.5996
# архаический_ADJ	0.5906
# позднеантичный_ADJ	0.5833
# позднейший_ADJ	0.5764
# новоевропейский_ADJ	0.5749
# античный_ADJ	0.5672
# v-vi_NUM	0.5586
#
# Words similar to шумозаградительный_ADJ:
# шум_NOUN	0.6955
# шум_PROPN	0.6918
# шум_NUM	0.645
# гул_NOUN	0.6148
# рокот_NOUN	0.602
# шума_NOUN	0.5997
# гам_NOUN	0.5936
# гомон_NOUN	0.573
# грады_NOUN	0.5693
# гул_VERB	0.5566
#
# Words similar to биокибернетик_NOUN:
# кибернетика_NOUN	0.8042
# генетика_NOUN	0.7062
# биофизик_NOUN	0.6996
# кибернетика_PROPN	0.6935
# биология_NOUN	0.6883
# инженерия_NOUN	0.6772
# биотехнология_NOUN	0.6705
# синергетика_PROPN	0.669
# социология_NOUN	0.6673
# биофизика_NOUN	0.6613
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top probabilities (corpus: Tayga, morphemic_model: CNN)
# ae-test_tagged
# Spearman correlation for human annotation: 0.5717
# p-value: 9.3031e-170
# OOV-pairs ratio: 0.0287
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top probabilities (corpus: Tayga, morphemic_model: CNN)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.8266
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0017
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top probabilities (corpus: Tayga, morphemic_model: CNN)
# hj-test_tagged
# Spearman correlation for human annotation: 0.7361
# p-value: 6.7629e-58
# OOV-pairs ratio: 0.0060
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top probabilities (corpus: Tayga, morphemic_model: CNN)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6842
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0082
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top morphemic F1 and frequency (corpus: Tayga, morphemic_model: CNN)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.7681
# p-value: 1.8241e-21
# OOV-pairs ratio: 0.0385
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# семьдесят_NUM	0.7653
# восемьдесят_NUM	0.7544
# двадцать_NUM	0.754
# тридцать_NUM	0.747
# шестьдесят_NUM	0.7361
# восемьдесят_VERB	0.7244
# пятьдесят_NUM	0.719
# сорок_NUM	0.7113
# девяносто_NUM	0.7067
# двести_NUM	0.6832
#
# Words similar to древневерхненемецкий_ADJ:
# верхний_NOUN	0.663
# верхний_ADJ	0.6588
# нижний_ADJ	0.6314
# древний_ADJ	0.6224
# древневосточный_ADJ	0.6219
# древнейший_ADJ	0.6076
# верхний_PROPN	0.6065
# древний_NOUN	0.5988
# -окский_ADJ	0.5961
# нижний_NOUN	0.5907
#
# Words similar to камнесамоцветный_ADJ:
# самоцветный_ADJ	0.7565
# самоцвет_NOUN	0.7539
# камень_NOUN	0.7228
# каменья_NOUN	0.6919
# камни_NOUN	0.6727
# камушек_NOUN	0.6346
# изумруд_NOUN	0.6275
# камння_NOUN	0.624
# камешек_NOUN	0.6139
# камне_NOUN	0.6075
#
# Words similar to раннеперестроечный_ADJ:
# перестроечный_ADJ	0.7896
# постперестроечный_ADJ	0.781
# постсоветский_ADJ	0.7532
# перестроечной_ADJ	0.7283
# позднесоветский_ADJ	0.7277
# раннесоветский_ADJ	0.7079
# послереволюционный_ADJ	0.676
# послесталинский_ADJ	0.6498
# горбачевский_ADJ	0.644
# послесоветский_ADJ	0.6427
#
# Words similar to шумозаградительный_ADJ:
# зашуметь_VERB	0.6732
# зашуметь_ADV	0.6651
# загудеть_VERB	0.6142
# загудеть_NOUN	0.5652
# заградитель_NOUN	0.5564
# загрохотать_VERB	0.5533
# шумить_VERB	0.5468
# шуметь_VERB	0.5437
# засвистеть_VERB	0.5418
# зашуметь_NOUN	0.5409
#
# Words similar to биокибернетик_NOUN:
# биофизик_NOUN	0.8253
# кибернетика_NOUN	0.8096
# физик_NOUN	0.7552
# биолог_NOUN	0.7545
# генетик_NOUN	0.7337
# биохимик_NOUN	0.7335
# биофизика_NOUN	0.726
# генетика_NOUN	0.7163
# кибернетика_PROPN	0.7052
# физика_NOUN	0.705
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top morphemic F1 and frequency (corpus: Tayga, morphemic_model: CNN)
# ae-test_tagged
# Spearman correlation for human annotation: 0.5756
# p-value: 1.4264e-172
# OOV-pairs ratio: 0.0287
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top morphemic F1 and frequency (corpus: Tayga, morphemic_model: CNN)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.8276
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0017
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top morphemic F1 and frequency (corpus: Tayga, morphemic_model: CNN)
# hj-test_tagged
# Spearman correlation for human annotation: 0.7376
# p-value: 3.0517e-58
# OOV-pairs ratio: 0.0060
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top morphemic F1 and frequency (corpus: Tayga, morphemic_model: CNN)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6976
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0082
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top morphemic F1 and probability (corpus: Tayga, morphemic_model: CNN)
# rare_multimorphemic_tagged
# Spearman correlation for human annotation: 0.7752
# p-value: 4.5304e-22
# OOV-pairs ratio: 0.0385
#
# Words similar to восемьсотпятидесятилетие_NOUN:
# семьдесят_NUM	0.755
# двадцать_NUM	0.7489
# восемьдесят_NUM	0.747
# тридцать_NUM	0.7379
# восемьдесят_VERB	0.7306
# шестьдесят_NUM	0.7227
# пятьдесят_NUM	0.7193
# сорок_NUM	0.7008
# девяносто_NUM	0.6999
# семьдесят_VERB	0.686
#
# Words similar to древневерхненемецкий_ADJ:
# верхний_NOUN	0.663
# верхний_ADJ	0.6588
# нижний_ADJ	0.6314
# древний_ADJ	0.6224
# древневосточный_ADJ	0.6219
# древнейший_ADJ	0.6076
# верхний_PROPN	0.6065
# древний_NOUN	0.5988
# -окский_ADJ	0.5961
# нижний_NOUN	0.5907
#
# Words similar to камнесамоцветный_ADJ:
# самоцветный_ADJ	0.7568
# самоцвет_NOUN	0.746
# камень_NOUN	0.7078
# каменья_NOUN	0.6878
# камни_NOUN	0.6602
# камння_NOUN	0.6335
# камушек_NOUN	0.6234
# изумруд_NOUN	0.6223
# камешек_NOUN	0.608
# алмаз_NOUN	0.6062
#
# Words similar to раннеперестроечный_ADJ:
# перестроечный_ADJ	0.7896
# постперестроечный_ADJ	0.781
# постсоветский_ADJ	0.7532
# перестроечной_ADJ	0.7283
# позднесоветский_ADJ	0.7277
# раннесоветский_ADJ	0.7079
# послереволюционный_ADJ	0.676
# послесталинский_ADJ	0.6498
# горбачевский_ADJ	0.644
# послесоветский_ADJ	0.6427
#
# Words similar to шумозаградительный_ADJ:
# зашуметь_VERB	0.6732
# зашуметь_ADV	0.6651
# загудеть_VERB	0.6142
# загудеть_NOUN	0.5652
# заградитель_NOUN	0.5564
# загрохотать_VERB	0.5533
# шумить_VERB	0.5468
# шуметь_VERB	0.5437
# засвистеть_VERB	0.5418
# зашуметь_NOUN	0.5409
#
# Words similar to биокибернетик_NOUN:
# кибернетика_NOUN	0.825
# биофизик_NOUN	0.8022
# биофизика_NOUN	0.7321
# кибернетика_PROPN	0.7212
# генетика_NOUN	0.7202
# физик_NOUN	0.7164
# кибернетикий_NOUN	0.7035
# физика_NOUN	0.7031
# биолог_NOUN	0.6986
# генетик_NOUN	0.6981
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top morphemic F1 and probability (corpus: Tayga, morphemic_model: CNN)
# ae-test_tagged
# Spearman correlation for human annotation: 0.5838
# p-value: 1.3184e-178
# OOV-pairs ratio: 0.0287
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top morphemic F1 and probability (corpus: Tayga, morphemic_model: CNN)
# ae2-test_tagged
# Spearman correlation for human annotation: 0.8270
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0017
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top morphemic F1 and probability (corpus: Tayga, morphemic_model: CNN)
# hj-test_tagged
# Spearman correlation for human annotation: 0.7376
# p-value: 3.0805e-58
# OOV-pairs ratio: 0.0060
# ----------------------------------------------------------------------------------------------------
#
# Word2vec + averaged with top morphemic F1 and probability (corpus: Tayga, morphemic_model: CNN)
# rt-test_tagged
# Spearman correlation for human annotation: 0.6984
# p-value: 0.0000e+00
# OOV-pairs ratio: 0.0082
# ----------------------------------------------------------------------------------------------------
